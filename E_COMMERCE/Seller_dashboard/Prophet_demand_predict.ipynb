# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.25.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.0.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.52)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/ORDER_PROD_CUS_REV.csv", encoding='utf-8')
df.head()
# Out:
#       order_id  order_item_id order_purchase_timestamp    seller_id  \
# 0  ORDER_75477              1      2018-09-13 08:59:02  SELLER_0452
# 1  ORDER_63604              1      2018-04-26 10:53:06  SELLER_0414
# 2  ORDER_05566              1      2019-01-14 14:33:31  SELLER_1637
# 3  ORDER_04632              1      2018-02-04 13:57:51  SELLER_1445
# 4  ORDER_61452              1      2018-05-15 21:42:34  SELLER_0581
#
#     p_product_id product_category_name  price  freight_value     customer_id  \
# 0  PRODUCT_23128            cool_stuff   58.9          13.29  CUSTOMER_58023
# 1  PRODUCT_24351              pet_shop  239.9          19.93  CUSTOMER_30341
# 2  PRODUCT_20226       furniture_decor  199.0          17.87  CUSTOMER_30949
# 3  PRODUCT_07878          garden_tools  199.9          18.14  CUSTOMER_06713
# 4  PRODUCT_03505        home_utilities   21.9          12.69  CUSTOMER_20396
#
#   customer_state     review_id  review_score
# 0             RJ  REVIEW_45875             5
# 1             SP  REVIEW_24615             4
# 2             MG  REVIEW_03775             5
# 3             SP  REVIEW_49155             5
# 4             MG  REVIEW_20134             4

# %%
df = df.drop(columns = ['order_item_id', 'p_product_id', 'customer_id', 'review_id'])
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score
# 0   58.9          13.29             RJ             5
# 1  239.9          19.93             SP             4
# 2  199.0          17.87             MG             5
# 3  199.9          18.14             SP             5
# 4   21.9          12.69             MG             4

# %%
# 범주 병합 # 여기서는 사용 안 함

category_mapping = {
    'agro_industry_and_commerce': 'agro_industry_and_commerce',
    'air_conditioning': 'air_conditioning',
    'arts': 'arts_and_crafts',
    'arts_and_crafts': 'arts_and_crafts',
    'audio': 'audio',
    'automotive': 'automotive',
    'baby': 'baby',
    'bed_bath_table': 'bed_bath_table',
    'bedroom_furniture': 'furniture',
    'blu_ray_dvds': 'blu_ray_dvds',
    'books_general_interest': 'books',
    'imported_books': 'books',
    'technical_books': 'books',
    'christmas_articles': 'christmas_articles',
    'cinema_photo': 'cinema_photo',
    'computers_accessories': 'computers_accessories',
    'consoles_games': 'consoles_games',
    'construction_tools': 'construction_tools',
    'construction_tools_construction': 'construction_tools',
    'construction_tools_garden': 'construction_tools',
    'construction_tools_lighting': 'construction_tools',
    'construction_tools_safety': 'construction_tools',
    'cool_stuff': 'cool_stuff',
    'diapers_hygiene': 'diapers_hygiene',
    'drinks': 'food_drinks',
    'food_drink': 'food_drinks',
    'electronics': 'electronics',
    'fashion_bags_accessories': 'fashion',
    'fashion_childrens_clothes': 'fashion',
    'fashion_mens_clothing': 'fashion',
    'fashion_shoes': 'fashion',
    'fashion_sport': 'fashion',
    'fashion_underwear_beachwear': 'fashion',
    'fashion_womens_clothing': 'fashion',
    'flowers': 'flowers',
    'food': 'food',
    'furniture_decor': 'furniture',
    'furniture_mattress_and_upholstery': 'furniture',
    'living_room_furniture': 'furniture',
    'office_furniture': 'furniture',
    'kitchen_laundry_room_dining_garden_furniture': 'furniture',
    'garden_tools': 'garden_tools',
    'health_beauty': 'health_beauty',
    'home_appliances': 'home_appliances',
    'home_appliances_2': 'home_appliances',
    'home_comfort': 'home_comfort',
    'home_comfort_2': 'home_comfort',
    'home_construction': 'home_construction',
    'home_utilities': 'home_utilities',
    'insurance_and_services': 'insurance_and_services',
    'landline_phones': 'landline_phones',
    'luggage_accessories': 'luggage_accessories',
    'marketplace': 'marketplace',
    'music': 'music',
    'musical_cds_dvds': 'music',
    'musical_instruments': 'music',
    'party_supplies': 'party_supplies',
    'pcs': 'pcs',
    'perfumery': 'perfumery',
    'pet_shop': 'pet_shop',
    'portable_home_oven_and_coffee': 'portable_home_oven_and_coffee',
    'signaling_and_security': 'signaling_and_security',
    'small_appliances': 'small_appliances',
    'sports_leisure': 'sports_leisure',
    'stationery': 'stationery',
    'tablets_printing_image': 'tablets_printing_image',
    'telephony': 'telephony',
    'the_kitchen': 'the_kitchen',
    'toys': 'toys',
    'watches_gifts': 'watches_gifts',
    'Unknown' : 'Unknown'
}

# %%
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_year'] = df['order_purchase_timestamp'].dt.year
df['order_month'] = df['order_purchase_timestamp'].dt.month
df['order_day'] = df['order_purchase_timestamp'].dt.day
df['order_hour'] = df['order_purchase_timestamp'].dt.hour

# %%
# 계절 정보를 컬럼으로 추가
# 봄 : 9, 10, 11, 여름 : 12, 1, 2, 가을 : 3, 4, 5, 겨울 : 6, 7, 8
def get_season(month):
    if month in [12, 1, 2]:
        return 'Summer'
    elif month in [3, 4, 5]:
        return 'Autumn'
    elif month in [6, 7, 8]:
        return 'Winter'
    else:
        return 'Spring'

df['season'] = df['order_month'].apply(get_season)
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score  order_year  order_month  \
# 0   58.9          13.29             RJ             5        2018            9
# 1  239.9          19.93             SP             4        2018            4
# 2  199.0          17.87             MG             5        2019            1
# 3  199.9          18.14             SP             5        2018            2
# 4   21.9          12.69             MG             4        2018            5
#
#    order_day  order_hour  season
# 0         13           8  Spring
# 1         26          10  Autumn
# 2         14          14  Summer
# 3          4          13  Summer
# 4         15          21  Autumn

# %%
df['order_date'] = df['order_purchase_timestamp'].dt.date
df['order_day_of_week'] = df['order_purchase_timestamp'].dt.dayofweek
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score  order_year  order_month  \
# 0   58.9          13.29             RJ             5        2018            9
# 1  239.9          19.93             SP             4        2018            4
# 2  199.0          17.87             MG             5        2019            1
# 3  199.9          18.14             SP             5        2018            2
# 4   21.9          12.69             MG             4        2018            5
#
#    order_day  order_hour  season  order_date  order_day_of_week
# 0         13           8  Spring  2018-09-13                  3
# 1         26          10  Autumn  2018-04-26                  3
# 2         14          14  Summer  2019-01-14                  0
# 3          4          13  Summer  2018-02-04                  6
# 4         15          21  Autumn  2018-05-15                  1

# %%
# 0: 주중, 1: 주말
df['is_weekend'] = df['order_purchase_timestamp'].dt.dayofweek.apply(lambda x: 1 if x >= 5 else 0)
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score  order_year  order_month  \
# 0   58.9          13.29             RJ             5        2018            9
# 1  239.9          19.93             SP             4        2018            4
# 2  199.0          17.87             MG             5        2019            1
# 3  199.9          18.14             SP             5        2018            2
# 4   21.9          12.69             MG             4        2018            5
#
#    order_day  order_hour  season  order_date  order_day_of_week  is_weekend
# 0         13           8  Spring  2018-09-13                  3           0
# 1         26          10  Autumn  2018-04-26                  3           0
# 2         14          14  Summer  2019-01-14                  0           0
# 3          4          13  Summer  2018-02-04                  6           1
# 4         15          21  Autumn  2018-05-15                  1           0

# %% [markdown]
# # 데이터 추출

# %%
practice_selected = ['order_date', 'product_category_name', 'season', 'is_weekend']
practice_df = df[practice_selected]
practice_df.head()
# Out:
#    order_date product_category_name  season  is_weekend
# 0  2018-09-13            cool_stuff  Spring           0
# 1  2018-04-26              pet_shop  Autumn           0
# 2  2019-01-14       furniture_decor  Summer           0
# 3  2018-02-04          garden_tools  Summer           1
# 4  2018-05-15        home_utilities  Autumn           0

# %%
practice_df['order_date'] = pd.to_datetime(practice_df['order_date'])

#'demand' 컬럼 추가
demand_df = practice_df.groupby(['order_date', 'product_category_name', 'season', 'is_weekend']).size().reset_index(name='demand')

demand_df.head(10)
# Out:
#   order_date product_category_name  season  is_weekend  demand
# 0 2017-10-03         fashion_shoes  Spring           0       1
# 1 2017-10-03       furniture_decor  Spring           0       2
# 2 2017-10-03        sports_leisure  Spring           0       3
# 3 2017-10-03                  toys  Spring           0       1
# 4 2017-10-03         watches_gifts  Spring           0       1
# 5 2017-10-04               Unknown  Spring           0       1
# 6 2017-10-04      air_conditioning  Spring           0       4
# 7 2017-10-04            automotive  Spring           0       1
# 8 2017-10-04                  baby  Spring           0       3
# 9 2017-10-04        bed_bath_table  Spring           0       2

# %% [markdown]
# # 7월 테스트셋 검증

# %%
import pandas as pd
from prophet import Prophet
from tqdm import tqdm

test_start_date = '2019-07-01'
test_end_date = '2019-07-31'

test_data = demand_df[(demand_df['order_date'] >= test_start_date) & (demand_df['order_date'] <= test_end_date)]

# 훈련 데이터셋에서 2019년 7월 데이터 제거
train_end_date = '2019-06-30'
demand_df_filtered = demand_df[demand_df['order_date'] <= train_end_date]

# 계절을 숫자로 매핑
def map_season(season):
    if season == 'Spring':
        return 1
    elif season == 'Summer':
        return 2
    elif season == 'Autumn':
        return 3
    elif season == 'Winter':
        return 4
    else:
        return 0  # 예외 처리

demand_df_filtered['season'] = demand_df_filtered['season'].apply(map_season)

def is_weekend(date):
    day_of_week = date.weekday()  # 0: 월요일, 6: 일요일
    return 1 if day_of_week >= 5 else 0  # 토요일(5), 일요일(6)은 주말로 처리

category_groups = demand_df_filtered.groupby('product_category_name')

results = pd.DataFrame()


for category, group in tqdm(category_groups, desc="Processing categories"):
    if category in test_data['product_category_name'].unique():  # 테스트 데이터셋에 해당 카테고리가 있는 경우에만 예측 수행

        group = group.rename(columns={'order_date': 'ds', 'demand': 'y', 'season': 'season', 'is_weekend': 'is_weekend'})
        group['is_weekend'] = group['ds'].apply(is_weekend)

        # Prophet 모델 생성 및 훈련 # 값이 크면 모델이 더 유연해지지만, 훈련 시간이 증가
        model = Prophet(growth ='linear',
                        n_changepoints = 25,
                        changepoint_range=0.8,
                        changepoint_prior_scale=0.05)

        # 계절 정보를 특성으로 추가
        model.add_regressor('season')
        model.add_regressor('is_weekend')

        model.fit(group[['ds', 'y', 'season', 'is_weekend']])

        future_dates = pd.date_range(start='2019-07-01', end='2019-07-31', freq='D')
        future = pd.DataFrame({'ds': future_dates})

        future['season'] = 4
        future['is_weekend'] = future['ds'].apply(is_weekend)

        forecast = model.predict(future)

        forecast['product_category_name'] = category
        forecast['order_date'] = forecast['ds']
        forecast['demand'] = forecast['yhat']
        results = pd.concat([results, forecast[['order_date', 'product_category_name','demand']]])
# Out:
# Processing categories:   0%|          | 0/72 [00:00<?, ?it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/om30twib.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/j9bweox9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76418', 'data', 'file=/tmp/tmpg1fephfb/om30twib.json', 'init=/tmp/tmpg1fephfb/j9bweox9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelxeoqui94/prophet_model-20240709030752.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   1%|▏         | 1/72 [00:00<00:39,  1.81it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/e5ut4w5_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/yop9i7c6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31715', 'data', 'file=/tmp/tmpg1fephfb/e5ut4w5_.json', 'init=/tmp/tmpg1fephfb/yop9i7c6.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelpbn39qc2/prophet_model-20240709030752.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   3%|▎         | 2/72 [00:00<00:24,  2.90it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nw_ulx66.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8ll15buw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34469', 'data', 'file=/tmp/tmpg1fephfb/nw_ulx66.json', 'init=/tmp/tmpg1fephfb/8ll15buw.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model68zbcb4p/prophet_model-20240709030752.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   4%|▍         | 3/72 [00:01<00:26,  2.63it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nd07b4g8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4nsiriua.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30199', 'data', 'file=/tmp/tmpg1fephfb/nd07b4g8.json', 'init=/tmp/tmpg1fephfb/4nsiriua.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelmc2awfrf/prophet_model-20240709030753.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   6%|▌         | 4/72 [00:01<00:26,  2.60it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 2.
# Processing categories:   7%|▋         | 5/72 [00:01<00:20,  3.29it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_f_7v5xe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cefq0vng.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40720', 'data', 'file=/tmp/tmpg1fephfb/_f_7v5xe.json', 'init=/tmp/tmpg1fephfb/cefq0vng.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modell4ah_25c/prophet_model-20240709030753.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   8%|▊         | 6/72 [00:02<00:24,  2.72it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/f0c54eyx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/53x9a76i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63099', 'data', 'file=/tmp/tmpg1fephfb/f0c54eyx.json', 'init=/tmp/tmpg1fephfb/53x9a76i.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modely2x84vt7/prophet_model-20240709030754.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  10%|▉         | 7/72 [00:02<00:30,  2.16it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/c95c_n15.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vlrx7lmi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36235', 'data', 'file=/tmp/tmpg1fephfb/c95c_n15.json', 'init=/tmp/tmpg1fephfb/vlrx7lmi.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model8a7iqao5/prophet_model-20240709030755.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  11%|█         | 8/72 [00:03<00:36,  1.77it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wsojhwvm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/i1ajk4mh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12626', 'data', 'file=/tmp/tmpg1fephfb/wsojhwvm.json', 'init=/tmp/tmpg1fephfb/i1ajk4mh.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model819cten1/prophet_model-20240709030755.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  12%|█▎        | 9/72 [00:04<00:39,  1.61it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/fpzeh1cj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/da3wu5kw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72685', 'data', 'file=/tmp/tmpg1fephfb/fpzeh1cj.json', 'init=/tmp/tmpg1fephfb/da3wu5kw.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model3z9tmcyp/prophet_model-20240709030756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:07:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  14%|█▍        | 10/72 [00:05<00:45,  1.37it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nq6ywcrj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vzrs4xdg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87012', 'data', 'file=/tmp/tmpg1fephfb/nq6ywcrj.json', 'init=/tmp/tmpg1fephfb/vzrs4xdg.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeld48eemrr/prophet_model-20240709030757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:07:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  15%|█▌        | 11/72 [00:06<00:52,  1.17it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/u8oe7l07.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t4q3qalw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72400', 'data', 'file=/tmp/tmpg1fephfb/u8oe7l07.json', 'init=/tmp/tmpg1fephfb/t4q3qalw.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model8ld0l6gv/prophet_model-20240709030758.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  17%|█▋        | 12/72 [00:06<00:39,  1.51it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/654nsd7o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8ux_agox.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17615', 'data', 'file=/tmp/tmpg1fephfb/654nsd7o.json', 'init=/tmp/tmpg1fephfb/8ux_agox.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelcbeu11_i/prophet_model-20240709030758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:07:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  18%|█▊        | 13/72 [00:07<00:37,  1.56it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6j3y0ut1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/whi24dge.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69667', 'data', 'file=/tmp/tmpg1fephfb/6j3y0ut1.json', 'init=/tmp/tmpg1fephfb/whi24dge.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model5a5az8hr/prophet_model-20240709030759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:07:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  19%|█▉        | 14/72 [00:07<00:32,  1.79it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/z5_s1q4d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ipwtcz9k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69504', 'data', 'file=/tmp/tmpg1fephfb/z5_s1q4d.json', 'init=/tmp/tmpg1fephfb/ipwtcz9k.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelmu0pqqog/prophet_model-20240709030759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:07:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:07:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  21%|██        | 15/72 [00:08<00:28,  1.99it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/u4ght2p2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/q7316n1s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44990', 'data', 'file=/tmp/tmpg1fephfb/u4ght2p2.json', 'init=/tmp/tmpg1fephfb/q7316n1s.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelpshx99o9/prophet_model-20240709030800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  22%|██▏       | 16/72 [00:08<00:26,  2.13it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/50h6dy5z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8dvcb33c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19093', 'data', 'file=/tmp/tmpg1fephfb/50h6dy5z.json', 'init=/tmp/tmpg1fephfb/8dvcb33c.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeltec6u00p/prophet_model-20240709030800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  24%|██▎       | 17/72 [00:08<00:25,  2.14it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vtj7qe78.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/u83jc2lj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80716', 'data', 'file=/tmp/tmpg1fephfb/vtj7qe78.json', 'init=/tmp/tmpg1fephfb/u83jc2lj.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model8aovqtpl/prophet_model-20240709030801.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  25%|██▌       | 18/72 [00:09<00:22,  2.40it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/e84tdhec.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/03r5kzr1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55293', 'data', 'file=/tmp/tmpg1fephfb/e84tdhec.json', 'init=/tmp/tmpg1fephfb/03r5kzr1.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modela4op2030/prophet_model-20240709030801.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  26%|██▋       | 19/72 [00:09<00:20,  2.55it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t4oo6jg1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/w2g2hbfl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28258', 'data', 'file=/tmp/tmpg1fephfb/t4oo6jg1.json', 'init=/tmp/tmpg1fephfb/w2g2hbfl.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbmduq0cw/prophet_model-20240709030801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  28%|██▊       | 20/72 [00:10<00:21,  2.42it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/om71mu5n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/gbkrhg4d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10996', 'data', 'file=/tmp/tmpg1fephfb/om71mu5n.json', 'init=/tmp/tmpg1fephfb/gbkrhg4d.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model_pvr2wio/prophet_model-20240709030802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  29%|██▉       | 21/72 [00:10<00:29,  1.76it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/odocanig.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ekznzr7n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23225', 'data', 'file=/tmp/tmpg1fephfb/odocanig.json', 'init=/tmp/tmpg1fephfb/ekznzr7n.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modell2d9t5r9/prophet_model-20240709030803.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  31%|███       | 22/72 [00:11<00:26,  1.89it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 14.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qdctyevq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wsylm57c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43374', 'data', 'file=/tmp/tmpg1fephfb/qdctyevq.json', 'init=/tmp/tmpg1fephfb/wsylm57c.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelwhiig7gt/prophet_model-20240709030803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  32%|███▏      | 23/72 [00:11<00:24,  1.96it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/m5mhnluc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1352cdnh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96630', 'data', 'file=/tmp/tmpg1fephfb/m5mhnluc.json', 'init=/tmp/tmpg1fephfb/1352cdnh.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelhv_iny7j/prophet_model-20240709030803.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  33%|███▎      | 24/72 [00:12<00:21,  2.18it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/bz3yooof.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/v227zhj7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1137', 'data', 'file=/tmp/tmpg1fephfb/bz3yooof.json', 'init=/tmp/tmpg1fephfb/v227zhj7.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelx0ini8_1/prophet_model-20240709030804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  35%|███▍      | 25/72 [00:12<00:20,  2.29it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pyt2tpyq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/jrivkpp5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27777', 'data', 'file=/tmp/tmpg1fephfb/pyt2tpyq.json', 'init=/tmp/tmpg1fephfb/jrivkpp5.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelh_h3rdj7/prophet_model-20240709030804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  36%|███▌      | 26/72 [00:13<00:21,  2.12it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/lxyn6n7b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_ox_3_e5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99025', 'data', 'file=/tmp/tmpg1fephfb/lxyn6n7b.json', 'init=/tmp/tmpg1fephfb/_ox_3_e5.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelmed6p8p3/prophet_model-20240709030805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  39%|███▉      | 28/72 [00:13<00:19,  2.22it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4z1e4cdp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/b3u77eyo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19076', 'data', 'file=/tmp/tmpg1fephfb/4z1e4cdp.json', 'init=/tmp/tmpg1fephfb/b3u77eyo.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelzz7ylrfb/prophet_model-20240709030806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  40%|████      | 29/72 [00:14<00:18,  2.31it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1lg9taxf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/g073odmz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88331', 'data', 'file=/tmp/tmpg1fephfb/1lg9taxf.json', 'init=/tmp/tmpg1fephfb/g073odmz.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelw4y5jnua/prophet_model-20240709030806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  43%|████▎     | 31/72 [00:14<00:13,  3.03it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 18.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nmyyg_cp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/2qv5h_cn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43162', 'data', 'file=/tmp/tmpg1fephfb/nmyyg_cp.json', 'init=/tmp/tmpg1fephfb/2qv5h_cn.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelx47x4v5d/prophet_model-20240709030806.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  46%|████▌     | 33/72 [00:15<00:10,  3.66it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_0czte12.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qfbe_ow_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68129', 'data', 'file=/tmp/tmpg1fephfb/_0czte12.json', 'init=/tmp/tmpg1fephfb/qfbe_ow_.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelaxxskuht/prophet_model-20240709030807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  47%|████▋     | 34/72 [00:15<00:12,  3.11it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6pxtrk20.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/oxbf9ozl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74331', 'data', 'file=/tmp/tmpg1fephfb/6pxtrk20.json', 'init=/tmp/tmpg1fephfb/oxbf9ozl.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelgg80exxw/prophet_model-20240709030807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  49%|████▊     | 35/72 [00:15<00:10,  3.45it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ha2c94l8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ldem76x9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62980', 'data', 'file=/tmp/tmpg1fephfb/ha2c94l8.json', 'init=/tmp/tmpg1fephfb/ldem76x9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeljuj46hr5/prophet_model-20240709030807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  50%|█████     | 36/72 [00:15<00:09,  3.81it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/94jigonv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/0oy3af4v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32943', 'data', 'file=/tmp/tmpg1fephfb/94jigonv.json', 'init=/tmp/tmpg1fephfb/0oy3af4v.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelp4xj3rs2/prophet_model-20240709030807.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  51%|█████▏    | 37/72 [00:16<00:08,  4.00it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4r53a6hz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/highv5w5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92752', 'data', 'file=/tmp/tmpg1fephfb/4r53a6hz.json', 'init=/tmp/tmpg1fephfb/highv5w5.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model15qlu73j/prophet_model-20240709030808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  53%|█████▎    | 38/72 [00:16<00:08,  4.12it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7_yjodqg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/v7yek8jh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99399', 'data', 'file=/tmp/tmpg1fephfb/7_yjodqg.json', 'init=/tmp/tmpg1fephfb/v7yek8jh.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model990xtq09/prophet_model-20240709030808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  54%|█████▍    | 39/72 [00:16<00:08,  3.88it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/laa03fgo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/s3jbj9hp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90343', 'data', 'file=/tmp/tmpg1fephfb/laa03fgo.json', 'init=/tmp/tmpg1fephfb/s3jbj9hp.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelt78i9j2h/prophet_model-20240709030808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  56%|█████▌    | 40/72 [00:16<00:08,  3.96it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pi0gaoxr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/04vngbpe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16443', 'data', 'file=/tmp/tmpg1fephfb/pi0gaoxr.json', 'init=/tmp/tmpg1fephfb/04vngbpe.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelytzbwh_b/prophet_model-20240709030808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  57%|█████▋    | 41/72 [00:17<00:07,  4.11it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/krcb_zp2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8wf0d6ok.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5717', 'data', 'file=/tmp/tmpg1fephfb/krcb_zp2.json', 'init=/tmp/tmpg1fephfb/8wf0d6ok.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbn2w4mq2/prophet_model-20240709030809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  58%|█████▊    | 42/72 [00:17<00:07,  3.96it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/gqogzwcp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/i55um4ga.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19182', 'data', 'file=/tmp/tmpg1fephfb/gqogzwcp.json', 'init=/tmp/tmpg1fephfb/i55um4ga.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelkkoigvzt/prophet_model-20240709030809.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  60%|█████▉    | 43/72 [00:17<00:07,  3.70it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t4zhq332.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/aggeoak9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41054', 'data', 'file=/tmp/tmpg1fephfb/t4zhq332.json', 'init=/tmp/tmpg1fephfb/aggeoak9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelb712ab9g/prophet_model-20240709030809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  61%|██████    | 44/72 [00:17<00:07,  3.93it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vecqdh8l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/2o38xl57.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45811', 'data', 'file=/tmp/tmpg1fephfb/vecqdh8l.json', 'init=/tmp/tmpg1fephfb/2o38xl57.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelqhc93yj5/prophet_model-20240709030810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  62%|██████▎   | 45/72 [00:18<00:07,  3.72it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/m8_li0bo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/i919wbuf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31739', 'data', 'file=/tmp/tmpg1fephfb/m8_li0bo.json', 'init=/tmp/tmpg1fephfb/i919wbuf.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeletby7iem/prophet_model-20240709030810.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  64%|██████▍   | 46/72 [00:18<00:07,  3.32it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9jajr0ug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4r6657j2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20831', 'data', 'file=/tmp/tmpg1fephfb/9jajr0ug.json', 'init=/tmp/tmpg1fephfb/4r6657j2.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelrmpingox/prophet_model-20240709030810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  65%|██████▌   | 47/72 [00:18<00:07,  3.54it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/q3ml38de.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9by2al73.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62303', 'data', 'file=/tmp/tmpg1fephfb/q3ml38de.json', 'init=/tmp/tmpg1fephfb/9by2al73.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelc40rh8j2/prophet_model-20240709030810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  68%|██████▊   | 49/72 [00:19<00:04,  4.82it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cdivskyz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/5vviqzp2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88048', 'data', 'file=/tmp/tmpg1fephfb/cdivskyz.json', 'init=/tmp/tmpg1fephfb/5vviqzp2.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelcnv7_qor/prophet_model-20240709030811.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  69%|██████▉   | 50/72 [00:19<00:04,  4.58it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/uuwq7m3t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t8subh3a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2756', 'data', 'file=/tmp/tmpg1fephfb/uuwq7m3t.json', 'init=/tmp/tmpg1fephfb/t8subh3a.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelpjumbwk9/prophet_model-20240709030811.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...
# 03:08:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  75%|███████▌  | 54/72 [00:20<00:04,  3.63it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/p_1x5xb3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ccbo_n3_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15819', 'data', 'file=/tmp/tmpg1fephfb/p_1x5xb3.json', 'init=/tmp/tmpg1fephfb/ccbo_n3_.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbsgu44ul/prophet_model-20240709030812.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  78%|███████▊  | 56/72 [00:20<00:03,  5.28it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wqr4kpk1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/64s8m75m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15659', 'data', 'file=/tmp/tmpg1fephfb/wqr4kpk1.json', 'init=/tmp/tmpg1fephfb/64s8m75m.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model9mcv6s9q/prophet_model-20240709030812.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  79%|███████▉  | 57/72 [00:20<00:02,  5.30it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/72sxoozb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/iepk2sid.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20971', 'data', 'file=/tmp/tmpg1fephfb/72sxoozb.json', 'init=/tmp/tmpg1fephfb/iepk2sid.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model89jk93fv/prophet_model-20240709030812.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  81%|████████  | 58/72 [00:21<00:03,  3.84it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cv2gol_e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/r_q9clza.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46493', 'data', 'file=/tmp/tmpg1fephfb/cv2gol_e.json', 'init=/tmp/tmpg1fephfb/r_q9clza.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model_hq2p5w9/prophet_model-20240709030813.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  82%|████████▏ | 59/72 [00:21<00:03,  3.43it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/k72fx48p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/jkju4yyt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10372', 'data', 'file=/tmp/tmpg1fephfb/k72fx48p.json', 'init=/tmp/tmpg1fephfb/jkju4yyt.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model0td_ujyp/prophet_model-20240709030813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  83%|████████▎ | 60/72 [00:21<00:03,  3.66it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6w33u9cs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/l4jvz9xh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88772', 'data', 'file=/tmp/tmpg1fephfb/6w33u9cs.json', 'init=/tmp/tmpg1fephfb/l4jvz9xh.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelr40nvos3/prophet_model-20240709030813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  85%|████████▍ | 61/72 [00:22<00:02,  4.11it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/mo2j8ghh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/p0wpxe2h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42591', 'data', 'file=/tmp/tmpg1fephfb/mo2j8ghh.json', 'init=/tmp/tmpg1fephfb/p0wpxe2h.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelgwvadpu9/prophet_model-20240709030814.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  86%|████████▌ | 62/72 [00:22<00:02,  4.18it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_dmv5tmn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/dpntldq9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11973', 'data', 'file=/tmp/tmpg1fephfb/_dmv5tmn.json', 'init=/tmp/tmpg1fephfb/dpntldq9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model74t6kvc5/prophet_model-20240709030814.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  88%|████████▊ | 63/72 [00:22<00:02,  3.89it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nak908do.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/htri6684.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95312', 'data', 'file=/tmp/tmpg1fephfb/nak908do.json', 'init=/tmp/tmpg1fephfb/htri6684.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model4zlx74hj/prophet_model-20240709030814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  89%|████████▉ | 64/72 [00:22<00:01,  4.26it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/0161ydka.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/lfzcbsv6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42345', 'data', 'file=/tmp/tmpg1fephfb/0161ydka.json', 'init=/tmp/tmpg1fephfb/lfzcbsv6.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model8hchd7wp/prophet_model-20240709030814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  90%|█████████ | 65/72 [00:23<00:01,  4.39it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/f7z21r8t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/zpglt32n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14469', 'data', 'file=/tmp/tmpg1fephfb/f7z21r8t.json', 'init=/tmp/tmpg1fephfb/zpglt32n.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modela8lanwji/prophet_model-20240709030815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  92%|█████████▏| 66/72 [00:23<00:01,  4.39it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hjtskvci.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ekmxorba.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70409', 'data', 'file=/tmp/tmpg1fephfb/hjtskvci.json', 'init=/tmp/tmpg1fephfb/ekmxorba.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbfezasj5/prophet_model-20240709030815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  94%|█████████▍| 68/72 [00:23<00:00,  5.90it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/r06onsnv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/jkewofvb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4980', 'data', 'file=/tmp/tmpg1fephfb/r06onsnv.json', 'init=/tmp/tmpg1fephfb/jkewofvb.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelvy0eyg3o/prophet_model-20240709030815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  96%|█████████▌| 69/72 [00:23<00:00,  5.52it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6w5jm01u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7mdafwz4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84539', 'data', 'file=/tmp/tmpg1fephfb/6w5jm01u.json', 'init=/tmp/tmpg1fephfb/7mdafwz4.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelied_ahx7/prophet_model-20240709030815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  99%|█████████▊| 71/72 [00:23<00:00,  6.65it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/mvl_91p9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/5yykumj4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61716', 'data', 'file=/tmp/tmpg1fephfb/mvl_91p9.json', 'init=/tmp/tmpg1fephfb/5yykumj4.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeltnq_2s55/prophet_model-20240709030815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories: 100%|██████████| 72/72 [00:24<00:00,  2.98it/s]

# %%
print(len(results))
results.tail()
# Out:
# 2015
#    order_date product_category_name     demand
# 26 2019-07-27         watches_gifts  18.574814
# 27 2019-07-28         watches_gifts  15.982368
# 28 2019-07-29         watches_gifts  16.857763
# 29 2019-07-30         watches_gifts  19.538880
# 30 2019-07-31         watches_gifts  18.814422

# %%
# 모든 날짜와 카테고리의 조합 생성
all_dates = pd.date_range(start=test_start_date, end=test_end_date, freq='D')
all_categories = test_data['product_category_name'].unique()
all_combinations = pd.MultiIndex.from_product([all_dates, all_categories], names=['order_date', 'product_category_name']).to_frame(index=False)

results = pd.merge(all_combinations, results, on=['order_date', 'product_category_name'], how='left')
test_data = pd.merge(all_combinations, test_data, on=['order_date', 'product_category_name'], how='left')


merged_results = pd.merge(results, test_data, on=['order_date', 'product_category_name'], how='inner')

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score, mean_squared_error

# NaN을 0으로 대체한 후 계산
mae = mean_absolute_error(merged_results['demand_x'].fillna(0), merged_results['demand_y'].fillna(0))
r2 = r2_score(merged_results['demand_x'].fillna(0), merged_results['demand_y'].fillna(0))
rmse = mean_squared_error(merged_results['demand_x'].fillna(0), merged_results['demand_y'].fillna(0), squared=False)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2) Score: {r2}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 2.496000502224008
# R-squared (R2) Score: 0.48385077702458634
# Root Mean Squared Error (RMSE): 4.171865956641915

# %%
# 판매량의 스케일과 비교하여 위의 평가지표가 어떤지 검토
sales_data = demand_df['demand']

# 기술 통계량 계산
stats = sales_data.describe()
print(stats)
# Out:
# count    17461.000000
# mean         5.750816
# std          7.079967
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          7.000000
# max        194.000000
# Name: demand, dtype: float64

# %% [markdown]
# ### MAE (2.496):
#
# 수요의 평균값(5.75)과 비교할 때 MAE가 약 2.496으로, 이는 비교적 적당한 오차로 보입니다. 특히 수요의 중앙값(3)과 비교했을 때 MAE는 상당히 낮습니다.
# 수요 데이터의 25%가 1 이하, 75%가 7 이하인 점을 고려할 때, MAE가 2.496이라면 이는 수요가 낮은 구간에서는 매우 양호한 성능을 보이는 것으로 해석될 수 있습니다.
#
# ### R2 Score (0.4838):
#
# R2 값이 0.4838이라면 이는 모델이 약 48.38%의 분산을 설명하고 있다는 의미입니다. 이는 데이터의 절반 가까이를 설명할 수 있는 수준으로, 매우 높은 설명력은 아니지만, 초기 모델로서는 적당한 수준입니다.
# 특히 판매량 예측에서 다양한 카테고리와 변동성을 고려할 때, 이 정도의 R2는 비교적 양호한 결과로 볼 수 있습니다.
#
# ### RMSE (4.1719):
#
# RMSE가 4.1719라는 것은 평균적으로 예측이 약 4.1719 정도의 오차를 가지고 있다는 것을 의미합니다. 이는 표준 편차(7.08)보다 낮아, 예측 오차가 데이터의 분산보다 작음을 나타냅니다.

# %% [markdown]
# # 8월 데이터셋에 모델 적용 & 예측

# %%
# 8월 데이터셋 만들기

def get_season(month):
    if month in [12, 1, 2]:
        return 2  
    elif month in [3, 4, 5]:
        return 3  
    elif month in [6, 7, 8]:
        return 4  
    else:
        return 1  

demand_df['season'] = demand_df['order_date'].dt.month.apply(get_season)

dates = pd.date_range(start='2019-08-01', end='2019-08-31', freq='D')

date_list = []

for date in dates:
    date_list.append({'date': date})

X_august = pd.DataFrame(date_list)
X_august['product_category_name'] = ''
X_august['is_weekend'] = X_august['date'].apply(lambda x: 1 if x.weekday() >= 5 else 0)
X_august['season'] = X_august['date'].dt.month.apply(get_season)

results = pd.DataFrame()

for category in demand_df['product_category_name'].unique():
    group = demand_df[demand_df['product_category_name'] == category]

    if not group.empty:

        group = group.rename(columns={'order_date': 'ds', 'demand': 'y', 'season': 'season', 'is_weekend': 'is_weekend'})

        model = Prophet()

        model.add_regressor('season')
        model.add_regressor('is_weekend')

        model.fit(group[['ds', 'y', 'season', 'is_weekend']])

        # 2019년 8월 1일부터 31일까지의 날짜 복사
        future = X_august.copy()
        future = future.rename(columns={'date': 'ds'})

        forecast = model.predict(future[['ds', 'season', 'is_weekend']])

        forecast['season'] = future['season'].values
        forecast['is_weekend'] = future['is_weekend'].values

        # 결과 저장  # 주말여부 및 계절 정보 함께 출력 -- 분석에 사용
        forecast['product_category_name'] = category
        forecast['order_date'] = forecast['ds']
        forecast['demand'] = forecast['yhat']
        results = pd.concat([results, forecast[['order_date', 'product_category_name', 'season', 'is_weekend', 'demand']]])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/gy1r8uzy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9zid9r7t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41941', 'data', 'file=/tmp/tmpg1fephfb/gy1r8uzy.json', 'init=/tmp/tmpg1fephfb/9zid9r7t.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeldlau2esn/prophet_model-20240709030816.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/2ogi6goe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/3bp9ty7y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22408', 'data', 'file=/tmp/tmpg1fephfb/2ogi6goe.json', 'init=/tmp/tmpg1fephfb/3bp9ty7y.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelz58uwocc/prophet_model-20240709030817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/h7ghjh8k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1n60lu2u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10297', 'data', 'file=/tmp/tmpg1fephfb/h7ghjh8k.json', 'init=/tmp/tmpg1fephfb/1n60lu2u.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeludb07xwb/prophet_model-20240709030817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/0r0vort5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/oe20q89z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91210', 'data', 'file=/tmp/tmpg1fephfb/0r0vort5.json', 'init=/tmp/tmpg1fephfb/oe20q89z.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelj8_r3n0k/prophet_model-20240709030817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/x17h83dw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/s0am7_ni.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88520', 'data', 'file=/tmp/tmpg1fephfb/x17h83dw.json', 'init=/tmp/tmpg1fephfb/s0am7_ni.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelw7now45u/prophet_model-20240709030817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/p_atnisv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7bk7n2hu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70638', 'data', 'file=/tmp/tmpg1fephfb/p_atnisv.json', 'init=/tmp/tmpg1fephfb/7bk7n2hu.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelj96_bkwz/prophet_model-20240709030817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vrsubnxx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/mms9vrls.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81280', 'data', 'file=/tmp/tmpg1fephfb/vrsubnxx.json', 'init=/tmp/tmpg1fephfb/mms9vrls.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelkjf7drbi/prophet_model-20240709030818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/msawg9r_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/xi06rbmv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34817', 'data', 'file=/tmp/tmpg1fephfb/msawg9r_.json', 'init=/tmp/tmpg1fephfb/xi06rbmv.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelk8paus8g/prophet_model-20240709030818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hg6o9kmn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/m0lwvivm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60082', 'data', 'file=/tmp/tmpg1fephfb/hg6o9kmn.json', 'init=/tmp/tmpg1fephfb/m0lwvivm.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model9iralhgm/prophet_model-20240709030818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/jvgrjrgb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/0meo8ggn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32464', 'data', 'file=/tmp/tmpg1fephfb/jvgrjrgb.json', 'init=/tmp/tmpg1fephfb/0meo8ggn.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelerlm0ysf/prophet_model-20240709030818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/imna2nqt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pzhlp_1l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63920', 'data', 'file=/tmp/tmpg1fephfb/imna2nqt.json', 'init=/tmp/tmpg1fephfb/pzhlp_1l.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbvjaxvlc/prophet_model-20240709030818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4vdzmosj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6u0y3gc4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8793', 'data', 'file=/tmp/tmpg1fephfb/4vdzmosj.json', 'init=/tmp/tmpg1fephfb/6u0y3gc4.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsl3p98id/prophet_model-20240709030819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/x8gh_z04.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/3762l9qq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82493', 'data', 'file=/tmp/tmpg1fephfb/x8gh_z04.json', 'init=/tmp/tmpg1fephfb/3762l9qq.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model0pp7eihn/prophet_model-20240709030819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wq00mexa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/gpe9os73.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10895', 'data', 'file=/tmp/tmpg1fephfb/wq00mexa.json', 'init=/tmp/tmpg1fephfb/gpe9os73.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelfy1f5joc/prophet_model-20240709030819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9_kh1p8w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/h0woypna.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11141', 'data', 'file=/tmp/tmpg1fephfb/9_kh1p8w.json', 'init=/tmp/tmpg1fephfb/h0woypna.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeleta9kxd9/prophet_model-20240709030819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/yaze7v70.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8h9qobra.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41407', 'data', 'file=/tmp/tmpg1fephfb/yaze7v70.json', 'init=/tmp/tmpg1fephfb/8h9qobra.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model9ni1j5fs/prophet_model-20240709030819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/mnibf8zn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/xpc3u9xs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95937', 'data', 'file=/tmp/tmpg1fephfb/mnibf8zn.json', 'init=/tmp/tmpg1fephfb/xpc3u9xs.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modell15edov0/prophet_model-20240709030820.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/kl9_ctue.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4znlzv2v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69833', 'data', 'file=/tmp/tmpg1fephfb/kl9_ctue.json', 'init=/tmp/tmpg1fephfb/4znlzv2v.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsfx9153v/prophet_model-20240709030820.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qpz9f49l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/0d1deec9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76751', 'data', 'file=/tmp/tmpg1fephfb/qpz9f49l.json', 'init=/tmp/tmpg1fephfb/0d1deec9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modellul4pfdl/prophet_model-20240709030820.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/v9z66syc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wufktqer.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95487', 'data', 'file=/tmp/tmpg1fephfb/v9z66syc.json', 'init=/tmp/tmpg1fephfb/wufktqer.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelacc_zdd0/prophet_model-20240709030820.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/2gt72mqj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_026_jq4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69973', 'data', 'file=/tmp/tmpg1fephfb/2gt72mqj.json', 'init=/tmp/tmpg1fephfb/_026_jq4.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeln8y6fe5e/prophet_model-20240709030820.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/f_j4ypgr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_342yn22.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75872', 'data', 'file=/tmp/tmpg1fephfb/f_j4ypgr.json', 'init=/tmp/tmpg1fephfb/_342yn22.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelm4kv3ces/prophet_model-20240709030821.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6kkt7vi3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/549csl42.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95307', 'data', 'file=/tmp/tmpg1fephfb/6kkt7vi3.json', 'init=/tmp/tmpg1fephfb/549csl42.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model3_jcjbar/prophet_model-20240709030821.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/zbrb47km.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/xgmicm5l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54238', 'data', 'file=/tmp/tmpg1fephfb/zbrb47km.json', 'init=/tmp/tmpg1fephfb/xgmicm5l.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeld8efoo05/prophet_model-20240709030821.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9a98fi36.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/908bupqr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3802', 'data', 'file=/tmp/tmpg1fephfb/9a98fi36.json', 'init=/tmp/tmpg1fephfb/908bupqr.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbajwc1op/prophet_model-20240709030821.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/k_h_do_q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/40qkmk1u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25488', 'data', 'file=/tmp/tmpg1fephfb/k_h_do_q.json', 'init=/tmp/tmpg1fephfb/40qkmk1u.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model2ognllfr/prophet_model-20240709030821.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/39u9jswm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9n7s197s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5422', 'data', 'file=/tmp/tmpg1fephfb/39u9jswm.json', 'init=/tmp/tmpg1fephfb/9n7s197s.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model4cr50pu9/prophet_model-20240709030822.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/duzs9d97.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/m33ks_84.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23423', 'data', 'file=/tmp/tmpg1fephfb/duzs9d97.json', 'init=/tmp/tmpg1fephfb/m33ks_84.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model405l27h4/prophet_model-20240709030822.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/io4qpvl7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/fjkfbvuj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74412', 'data', 'file=/tmp/tmpg1fephfb/io4qpvl7.json', 'init=/tmp/tmpg1fephfb/fjkfbvuj.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model97aj0j3w/prophet_model-20240709030822.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/zxtt_742.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/0vndti82.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24537', 'data', 'file=/tmp/tmpg1fephfb/zxtt_742.json', 'init=/tmp/tmpg1fephfb/0vndti82.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeli0pnuw_j/prophet_model-20240709030822.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wbqvn6au.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/by_f71g7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92725', 'data', 'file=/tmp/tmpg1fephfb/wbqvn6au.json', 'init=/tmp/tmpg1fephfb/by_f71g7.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelnek3e_k6/prophet_model-20240709030823.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/y4mpq2dz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/58gzld74.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14492', 'data', 'file=/tmp/tmpg1fephfb/y4mpq2dz.json', 'init=/tmp/tmpg1fephfb/58gzld74.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model_993ay_f/prophet_model-20240709030823.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/tmv8r4a4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9mz7k91s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50673', 'data', 'file=/tmp/tmpg1fephfb/tmv8r4a4.json', 'init=/tmp/tmpg1fephfb/9mz7k91s.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelvwpdmmqq/prophet_model-20240709030824.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6d5kngo1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/m9or4smf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99119', 'data', 'file=/tmp/tmpg1fephfb/6d5kngo1.json', 'init=/tmp/tmpg1fephfb/m9or4smf.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelkbh2q1az/prophet_model-20240709030824.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1rmdkzjx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/3c38f6ij.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55188', 'data', 'file=/tmp/tmpg1fephfb/1rmdkzjx.json', 'init=/tmp/tmpg1fephfb/3c38f6ij.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model9hxk2ymo/prophet_model-20240709030824.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/78r8dp0o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wc7l1sr7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7167', 'data', 'file=/tmp/tmpg1fephfb/78r8dp0o.json', 'init=/tmp/tmpg1fephfb/wc7l1sr7.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelt7sxpfta/prophet_model-20240709030824.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/adi95t11.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7vhny6n_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5663', 'data', 'file=/tmp/tmpg1fephfb/adi95t11.json', 'init=/tmp/tmpg1fephfb/7vhny6n_.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model72b8knmd/prophet_model-20240709030825.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/sdosqzgc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pknxd31t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85186', 'data', 'file=/tmp/tmpg1fephfb/sdosqzgc.json', 'init=/tmp/tmpg1fephfb/pknxd31t.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeldl7s6jr8/prophet_model-20240709030825.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 0.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cw454jeg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vgysmqes.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90875', 'data', 'file=/tmp/tmpg1fephfb/cw454jeg.json', 'init=/tmp/tmpg1fephfb/vgysmqes.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelvqkvhcqm/prophet_model-20240709030825.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qnnvzrdu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qrk8rbfq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70817', 'data', 'file=/tmp/tmpg1fephfb/qnnvzrdu.json', 'init=/tmp/tmpg1fephfb/qrk8rbfq.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model8s_w45sc/prophet_model-20240709030826.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/g56bwhzz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/tq6ifkxo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55218', 'data', 'file=/tmp/tmpg1fephfb/g56bwhzz.json', 'init=/tmp/tmpg1fephfb/tq6ifkxo.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelyk79o3cx/prophet_model-20240709030826.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t4mycng2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/y0gjavcl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32112', 'data', 'file=/tmp/tmpg1fephfb/t4mycng2.json', 'init=/tmp/tmpg1fephfb/y0gjavcl.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelcnohbb0w/prophet_model-20240709030826.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/eyknh79d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pratnmzk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90052', 'data', 'file=/tmp/tmpg1fephfb/eyknh79d.json', 'init=/tmp/tmpg1fephfb/pratnmzk.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeljeieyfoj/prophet_model-20240709030826.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7kyayj88.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/5o6m9fct.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96700', 'data', 'file=/tmp/tmpg1fephfb/7kyayj88.json', 'init=/tmp/tmpg1fephfb/5o6m9fct.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelgztik5db/prophet_model-20240709030826.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/rmdnh0iq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ypmywmc0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39093', 'data', 'file=/tmp/tmpg1fephfb/rmdnh0iq.json', 'init=/tmp/tmpg1fephfb/ypmywmc0.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelnr4ocxqg/prophet_model-20240709030827.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/35gwf3l4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/bcellwvj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57230', 'data', 'file=/tmp/tmpg1fephfb/35gwf3l4.json', 'init=/tmp/tmpg1fephfb/bcellwvj.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modell8iiuhsu/prophet_model-20240709030827.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/eeqqky73.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/zm9j44m9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47626', 'data', 'file=/tmp/tmpg1fephfb/eeqqky73.json', 'init=/tmp/tmpg1fephfb/zm9j44m9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelye7lxadp/prophet_model-20240709030827.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/f08gaxkt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/gtgmws52.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62852', 'data', 'file=/tmp/tmpg1fephfb/f08gaxkt.json', 'init=/tmp/tmpg1fephfb/gtgmws52.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsofd4g33/prophet_model-20240709030828.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/04sn_yyc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6rlxvtu8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46157', 'data', 'file=/tmp/tmpg1fephfb/04sn_yyc.json', 'init=/tmp/tmpg1fephfb/6rlxvtu8.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeled31bs20/prophet_model-20240709030828.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/76el_ehw.json
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t5w2rtil.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_v8lb5s8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64606', 'data', 'file=/tmp/tmpg1fephfb/t5w2rtil.json', 'init=/tmp/tmpg1fephfb/_v8lb5s8.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelukbza2dh/prophet_model-20240709030829.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hv1itnbl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qpias6x9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62438', 'data', 'file=/tmp/tmpg1fephfb/hv1itnbl.json', 'init=/tmp/tmpg1fephfb/qpias6x9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeljve1pue9/prophet_model-20240709030829.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/e8_q4k14.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/xsh8xdq4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36594', 'data', 'file=/tmp/tmpg1fephfb/e8_q4k14.json', 'init=/tmp/tmpg1fephfb/xsh8xdq4.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model2fozpczj/prophet_model-20240709030829.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6s6r__d5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/041q35pu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70252', 'data', 'file=/tmp/tmpg1fephfb/6s6r__d5.json', 'init=/tmp/tmpg1fephfb/041q35pu.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelrc58bp3f/prophet_model-20240709030829.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_xhfhv_u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/6yuvikh3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77972', 'data', 'file=/tmp/tmpg1fephfb/_xhfhv_u.json', 'init=/tmp/tmpg1fephfb/6yuvikh3.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model8uv4ylp1/prophet_model-20240709030830.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/fg2qaqta.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/endj6ipt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16351', 'data', 'file=/tmp/tmpg1fephfb/fg2qaqta.json', 'init=/tmp/tmpg1fephfb/endj6ipt.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeljs7zofq9/prophet_model-20240709030830.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/tj0i_mtc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/5_e8lm41.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71376', 'data', 'file=/tmp/tmpg1fephfb/tj0i_mtc.json', 'init=/tmp/tmpg1fephfb/5_e8lm41.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelq9zp_eny/prophet_model-20240709030830.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ur9mhxkt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/kga4zpls.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18186', 'data', 'file=/tmp/tmpg1fephfb/ur9mhxkt.json', 'init=/tmp/tmpg1fephfb/kga4zpls.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelx9z3d1r2/prophet_model-20240709030830.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cuqykabo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hx1ztffd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85711', 'data', 'file=/tmp/tmpg1fephfb/cuqykabo.json', 'init=/tmp/tmpg1fephfb/hx1ztffd.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model3zy2owbw/prophet_model-20240709030831.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 6.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vut50wgp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/05xa3tjl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99588', 'data', 'file=/tmp/tmpg1fephfb/vut50wgp.json', 'init=/tmp/tmpg1fephfb/05xa3tjl.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelp6wiuie_/prophet_model-20240709030831.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/m7zp5uio.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hyoyq891.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48669', 'data', 'file=/tmp/tmpg1fephfb/m7zp5uio.json', 'init=/tmp/tmpg1fephfb/hyoyq891.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelhsekk60h/prophet_model-20240709030831.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ffv5mglu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/iemcwilv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47525', 'data', 'file=/tmp/tmpg1fephfb/ffv5mglu.json', 'init=/tmp/tmpg1fephfb/iemcwilv.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsod87m9t/prophet_model-20240709030832.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/14z01g29.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_7wm2mo0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96848', 'data', 'file=/tmp/tmpg1fephfb/14z01g29.json', 'init=/tmp/tmpg1fephfb/_7wm2mo0.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelvs0g9qe8/prophet_model-20240709030832.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 17.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hm0zspvj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/j9nvtrlo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9178', 'data', 'file=/tmp/tmpg1fephfb/hm0zspvj.json', 'init=/tmp/tmpg1fephfb/j9nvtrlo.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model6mvu6bml/prophet_model-20240709030832.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_8zgpkuh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/le0bhz3v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80498', 'data', 'file=/tmp/tmpg1fephfb/_8zgpkuh.json', 'init=/tmp/tmpg1fephfb/le0bhz3v.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelydedxb23/prophet_model-20240709030832.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cn909vk9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/er58plbs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94422', 'data', 'file=/tmp/tmpg1fephfb/cn909vk9.json', 'init=/tmp/tmpg1fephfb/er58plbs.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modela84in6cq/prophet_model-20240709030832.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
results['is_weekend'] = results['is_weekend'].astype(int)
results['season'] = results['season'].astype(int)

results.head(15) # 정수로 표시되었는지 확인
# Out:
#    order_date product_category_name  season  is_weekend    demand
# 0  2019-08-01         fashion_shoes       4           0  1.366129
# 1  2019-08-02         fashion_shoes       4           0  1.290840
# 2  2019-08-03         fashion_shoes       4           1  1.128064
# 3  2019-08-04         fashion_shoes       4           1  1.192414
# 4  2019-08-05         fashion_shoes       4           0  1.114627
# 5  2019-08-06         fashion_shoes       4           0  1.409516
# 6  2019-08-07         fashion_shoes       4           0  1.060140
# 7  2019-08-08         fashion_shoes       4           0  1.362917
# 8  2019-08-09         fashion_shoes       4           0  1.287628
# 9  2019-08-10         fashion_shoes       4           1  1.124852
# 10 2019-08-11         fashion_shoes       4           1  1.189202
# 11 2019-08-12         fashion_shoes       4           0  1.111415
# 12 2019-08-13         fashion_shoes       4           0  1.406304
# 13 2019-08-14         fashion_shoes       4           0  1.056928
# 14 2019-08-15         fashion_shoes       4           0  1.359705

# %%
results_august = results.copy()
results_august.head()
# Out:
#   order_date product_category_name  season  is_weekend    demand
# 0 2019-08-01         fashion_shoes       4           0  1.366129
# 1 2019-08-02         fashion_shoes       4           0  1.290840
# 2 2019-08-03         fashion_shoes       4           1  1.128064
# 3 2019-08-04         fashion_shoes       4           1  1.192414
# 4 2019-08-05         fashion_shoes       4           0  1.114627

# %%
results_august.to_csv('results_august.csv', index=False)

# %%
category_demand = results_august.groupby('product_category_name')['demand'].sum().reset_index()

category_demand = category_demand.sort_values(by='demand', ascending=False)

top_5_categories = category_demand.head(10)

print("8월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:")
print(top_5_categories)
# Out:
# 8월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:
#     product_category_name      demand
# 38          health_beauty  773.258055
# 8          bed_bath_table  622.618686
# 44         home_utilities  563.124970
# 71          watches_gifts  525.073690
# 35        furniture_decor  394.037190
# 64         sports_leisure  280.994785
# 6              automotive  269.392456
# 7                    baby  217.834986
# 37           garden_tools  191.840781
# 14  computers_accessories  191.357037

# %% [markdown]
# # 9월 데이터셋에도 적용

# %%
# 2019년 9월 데이터셋 만들기

def get_season(month):
    if month in [12, 1, 2]:
        return 2  
    elif month in [3, 4, 5]:
        return 3  
    elif month in [6, 7, 8]:
        return 4  
    else:
        return 1  

demand_df['season'] = demand_df['order_date'].dt.month.apply(get_season)

dates = pd.date_range(start='2019-09-01', end='2019-09-30', freq='D')

date_list = []

for date in dates:
    date_list.append({'date': date})

X_september = pd.DataFrame(date_list)

X_september['product_category_name'] = ''

X_september['is_weekend'] = X_september['date'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

X_september['season'] = X_september['date'].dt.month.apply(get_season)

X_september.head()
# Out:
#         date product_category_name  is_weekend  season
# 0 2019-09-01                                 1       1
# 1 2019-09-02                                 0       1
# 2 2019-09-03                                 0       1
# 3 2019-09-04                                 0       1
# 4 2019-09-05                                 0       1

# %%
# 카테고리별로 모델을 훈련하고 예측
results = pd.DataFrame()

for category in demand_df['product_category_name'].unique():
    group = demand_df[demand_df['product_category_name'] == category]

    if not group.empty:  # 카테고리가 존재하는 경우에만 진행

        group = group.rename(columns={'order_date': 'ds', 'demand': 'y', 'season': 'season', 'is_weekend': 'is_weekend'})

        model = Prophet()

        model.add_regressor('season')
        model.add_regressor('is_weekend')

        model.fit(group[['ds', 'y', 'season', 'is_weekend']])

        future = X_september.rename(columns={'date': 'ds'})

        future['season'] = future['ds'].dt.month.apply(get_season)
        future['is_weekend'] = future['ds'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

        forecast = model.predict(future)

        forecast['season'] = future['season'].values
        forecast['is_weekend'] = future['is_weekend'].values

        # 결과 저장  # 주말여부 및 계절 정보 함께 출력 -- 분석에 사용
        forecast['product_category_name'] = category
        forecast['order_date'] = forecast['ds']
        forecast['demand'] = forecast['yhat']
        results = pd.concat([results, forecast[['order_date', 'product_category_name', 'demand', 'season', 'is_weekend']]])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/g8eziyws.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/2rlzfig2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23150', 'data', 'file=/tmp/tmpg1fephfb/g8eziyws.json', 'init=/tmp/tmpg1fephfb/2rlzfig2.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelu1szzy2_/prophet_model-20240709030833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/sgioxtad.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/w8o19xir.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5018', 'data', 'file=/tmp/tmpg1fephfb/sgioxtad.json', 'init=/tmp/tmpg1fephfb/w8o19xir.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model_vihyur1/prophet_model-20240709030833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1fmcbtxw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/5hokp44g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90560', 'data', 'file=/tmp/tmpg1fephfb/1fmcbtxw.json', 'init=/tmp/tmpg1fephfb/5hokp44g.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelvsiyeu7x/prophet_model-20240709030833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/88y35awe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/bo41jpln.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72663', 'data', 'file=/tmp/tmpg1fephfb/88y35awe.json', 'init=/tmp/tmpg1fephfb/bo41jpln.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model99_kwvef/prophet_model-20240709030833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/d9ajj4de.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/chdk0ldc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30971', 'data', 'file=/tmp/tmpg1fephfb/d9ajj4de.json', 'init=/tmp/tmpg1fephfb/chdk0ldc.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model9xv8vx77/prophet_model-20240709030833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4dheqjxb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/dzdut1zt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44598', 'data', 'file=/tmp/tmpg1fephfb/4dheqjxb.json', 'init=/tmp/tmpg1fephfb/dzdut1zt.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsqorvkhq/prophet_model-20240709030834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/rv_w9qz1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/majv3lbf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16061', 'data', 'file=/tmp/tmpg1fephfb/rv_w9qz1.json', 'init=/tmp/tmpg1fephfb/majv3lbf.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modele1ytxzya/prophet_model-20240709030834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9186d6le.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/p0ys56j8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95147', 'data', 'file=/tmp/tmpg1fephfb/9186d6le.json', 'init=/tmp/tmpg1fephfb/p0ys56j8.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model16xfld6x/prophet_model-20240709030834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qabl_slg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ybe4nhkj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30583', 'data', 'file=/tmp/tmpg1fephfb/qabl_slg.json', 'init=/tmp/tmpg1fephfb/ybe4nhkj.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modellle6mw0d/prophet_model-20240709030834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/xc23rrrw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/q2a1d2ek.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3935', 'data', 'file=/tmp/tmpg1fephfb/xc23rrrw.json', 'init=/tmp/tmpg1fephfb/q2a1d2ek.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelk7e388hd/prophet_model-20240709030834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/i658b3wv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/br8f8ut9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9266', 'data', 'file=/tmp/tmpg1fephfb/i658b3wv.json', 'init=/tmp/tmpg1fephfb/br8f8ut9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_models89pjqo_/prophet_model-20240709030835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8th_ilas.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nkvp_um9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2407', 'data', 'file=/tmp/tmpg1fephfb/8th_ilas.json', 'init=/tmp/tmpg1fephfb/nkvp_um9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelu20ofvr3/prophet_model-20240709030835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/f0zyg80q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vdkwa27o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56329', 'data', 'file=/tmp/tmpg1fephfb/f0zyg80q.json', 'init=/tmp/tmpg1fephfb/vdkwa27o.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelmvnakqiv/prophet_model-20240709030835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pyh7xu1f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_u_fy208.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75798', 'data', 'file=/tmp/tmpg1fephfb/pyh7xu1f.json', 'init=/tmp/tmpg1fephfb/_u_fy208.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelr150ggix/prophet_model-20240709030835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9i08dz9z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/dijepxuv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31932', 'data', 'file=/tmp/tmpg1fephfb/9i08dz9z.json', 'init=/tmp/tmpg1fephfb/dijepxuv.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelh8ruzc5_/prophet_model-20240709030836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/guv787rm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/d0z2nsm7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57618', 'data', 'file=/tmp/tmpg1fephfb/guv787rm.json', 'init=/tmp/tmpg1fephfb/d0z2nsm7.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelrexdouk7/prophet_model-20240709030836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1k54f3gq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/aqdhidqd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=840', 'data', 'file=/tmp/tmpg1fephfb/1k54f3gq.json', 'init=/tmp/tmpg1fephfb/aqdhidqd.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelx0aljrv8/prophet_model-20240709030836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/38ljw190.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1g5p0e_q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84691', 'data', 'file=/tmp/tmpg1fephfb/38ljw190.json', 'init=/tmp/tmpg1fephfb/1g5p0e_q.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelbobwt86k/prophet_model-20240709030837.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/o819sqxp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/o50kvtnx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73451', 'data', 'file=/tmp/tmpg1fephfb/o819sqxp.json', 'init=/tmp/tmpg1fephfb/o50kvtnx.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelueptgszd/prophet_model-20240709030837.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nv_ei6db.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/y79y4qas.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58032', 'data', 'file=/tmp/tmpg1fephfb/nv_ei6db.json', 'init=/tmp/tmpg1fephfb/y79y4qas.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelviyy7ff3/prophet_model-20240709030837.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/rpzv6s0i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wfnwnf61.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62279', 'data', 'file=/tmp/tmpg1fephfb/rpzv6s0i.json', 'init=/tmp/tmpg1fephfb/wfnwnf61.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modele5ph4rnc/prophet_model-20240709030837.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/kaioj1ho.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/km1jwynm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65839', 'data', 'file=/tmp/tmpg1fephfb/kaioj1ho.json', 'init=/tmp/tmpg1fephfb/km1jwynm.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelqbe7zd4i/prophet_model-20240709030838.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8tdpuer4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/i6pm36g0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59633', 'data', 'file=/tmp/tmpg1fephfb/8tdpuer4.json', 'init=/tmp/tmpg1fephfb/i6pm36g0.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelzapg5o_j/prophet_model-20240709030838.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/rikeu2pz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/p41ta0ok.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57554', 'data', 'file=/tmp/tmpg1fephfb/rikeu2pz.json', 'init=/tmp/tmpg1fephfb/p41ta0ok.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modell_9w17ro/prophet_model-20240709030839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/omn0pu7g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/h1063cij.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70076', 'data', 'file=/tmp/tmpg1fephfb/omn0pu7g.json', 'init=/tmp/tmpg1fephfb/h1063cij.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelvbna554f/prophet_model-20240709030839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nmiave0l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/4ey6yg10.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44796', 'data', 'file=/tmp/tmpg1fephfb/nmiave0l.json', 'init=/tmp/tmpg1fephfb/4ey6yg10.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelde_phxkp/prophet_model-20240709030839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qhz9y7k7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7eel4v5n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95710', 'data', 'file=/tmp/tmpg1fephfb/qhz9y7k7.json', 'init=/tmp/tmpg1fephfb/7eel4v5n.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model2wmg0xvp/prophet_model-20240709030839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/cta_8y9n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/j19yg4_n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22210', 'data', 'file=/tmp/tmpg1fephfb/cta_8y9n.json', 'init=/tmp/tmpg1fephfb/j19yg4_n.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelgp3ra3f8/prophet_model-20240709030839.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/u61hx0uo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/51xdc4js.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62612', 'data', 'file=/tmp/tmpg1fephfb/u61hx0uo.json', 'init=/tmp/tmpg1fephfb/51xdc4js.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model7_mhozpq/prophet_model-20240709030840.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7fdxbr9h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/my0i9jul.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18296', 'data', 'file=/tmp/tmpg1fephfb/7fdxbr9h.json', 'init=/tmp/tmpg1fephfb/my0i9jul.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelmsfq7znw/prophet_model-20240709030840.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/h0znsy0l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1zst_ro7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64431', 'data', 'file=/tmp/tmpg1fephfb/h0znsy0l.json', 'init=/tmp/tmpg1fephfb/1zst_ro7.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model25b02kx6/prophet_model-20240709030840.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/s_k6zhfi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/poqbkc05.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9201', 'data', 'file=/tmp/tmpg1fephfb/s_k6zhfi.json', 'init=/tmp/tmpg1fephfb/poqbkc05.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modellib392nh/prophet_model-20240709030840.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/g8zv1qsr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9mt2m_ti.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30217', 'data', 'file=/tmp/tmpg1fephfb/g8zv1qsr.json', 'init=/tmp/tmpg1fephfb/9mt2m_ti.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelamc7819y/prophet_model-20240709030841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/n9rb33yg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nkj2cez9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22044', 'data', 'file=/tmp/tmpg1fephfb/n9rb33yg.json', 'init=/tmp/tmpg1fephfb/nkj2cez9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modellfmd3ifz/prophet_model-20240709030841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/2xiuh1cy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/mf52f89o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74493', 'data', 'file=/tmp/tmpg1fephfb/2xiuh1cy.json', 'init=/tmp/tmpg1fephfb/mf52f89o.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model9qwyjme6/prophet_model-20240709030841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/407yu64f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/15xvnpwn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21931', 'data', 'file=/tmp/tmpg1fephfb/407yu64f.json', 'init=/tmp/tmpg1fephfb/15xvnpwn.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeljpj3mrtn/prophet_model-20240709030841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/64c9pwb1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/8sp857ip.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99114', 'data', 'file=/tmp/tmpg1fephfb/64c9pwb1.json', 'init=/tmp/tmpg1fephfb/8sp857ip.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modele4xf5_z9/prophet_model-20240709030841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ld2rbh5v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/zifhg7zs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61825', 'data', 'file=/tmp/tmpg1fephfb/ld2rbh5v.json', 'init=/tmp/tmpg1fephfb/zifhg7zs.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelfb6s9ie9/prophet_model-20240709030842.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 0.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/nlbeorz1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/bpaitrp6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64618', 'data', 'file=/tmp/tmpg1fephfb/nlbeorz1.json', 'init=/tmp/tmpg1fephfb/bpaitrp6.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelkul4kgln/prophet_model-20240709030842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/yue472kg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wc8dyxp5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19303', 'data', 'file=/tmp/tmpg1fephfb/yue472kg.json', 'init=/tmp/tmpg1fephfb/wc8dyxp5.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeldptbxpas/prophet_model-20240709030842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/3k9a8_76.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/kzeb_q3a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74836', 'data', 'file=/tmp/tmpg1fephfb/3k9a8_76.json', 'init=/tmp/tmpg1fephfb/kzeb_q3a.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelz4us4tza/prophet_model-20240709030842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/z2nqy99t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/lmhlallr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68675', 'data', 'file=/tmp/tmpg1fephfb/z2nqy99t.json', 'init=/tmp/tmpg1fephfb/lmhlallr.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelw13rsoud/prophet_model-20240709030842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/k910x7g6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/kxl9dag2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14127', 'data', 'file=/tmp/tmpg1fephfb/k910x7g6.json', 'init=/tmp/tmpg1fephfb/kxl9dag2.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsd21zri1/prophet_model-20240709030843.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/qdmk22w7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/90d5grf5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96085', 'data', 'file=/tmp/tmpg1fephfb/qdmk22w7.json', 'init=/tmp/tmpg1fephfb/90d5grf5.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelgoxkfzqn/prophet_model-20240709030843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vzgc7z5x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/bj89iv4u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13316', 'data', 'file=/tmp/tmpg1fephfb/vzgc7z5x.json', 'init=/tmp/tmpg1fephfb/bj89iv4u.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model095y3ttz/prophet_model-20240709030843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/c0o_c31j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/vsxx_h2j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36299', 'data', 'file=/tmp/tmpg1fephfb/c0o_c31j.json', 'init=/tmp/tmpg1fephfb/vsxx_h2j.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model06yvkv73/prophet_model-20240709030843.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/v5z2_1va.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/e03fg51v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23141', 'data', 'file=/tmp/tmpg1fephfb/v5z2_1va.json', 'init=/tmp/tmpg1fephfb/e03fg51v.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model4q60zpmf/prophet_model-20240709030844.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/t8ktyt4d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/p3ka7r7e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30691', 'data', 'file=/tmp/tmpg1fephfb/t8ktyt4d.json', 'init=/tmp/tmpg1fephfb/p3ka7r7e.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelcq_gxzod/prophet_model-20240709030844.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/_uxifuth.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/7hl9563d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3605', 'data', 'file=/tmp/tmpg1fephfb/_uxifuth.json', 'init=/tmp/tmpg1fephfb/7hl9563d.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model1d73i85l/prophet_model-20240709030844.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/g72hg9_r.json
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/rt2oan5_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/q21xsq4t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43335', 'data', 'file=/tmp/tmpg1fephfb/rt2oan5_.json', 'init=/tmp/tmpg1fephfb/q21xsq4t.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelklof2e8v/prophet_model-20240709030845.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/jhnu42eo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pav7evmm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51682', 'data', 'file=/tmp/tmpg1fephfb/jhnu42eo.json', 'init=/tmp/tmpg1fephfb/pav7evmm.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeld3qipsn_/prophet_model-20240709030845.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1ml5888t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/itrwwij4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2691', 'data', 'file=/tmp/tmpg1fephfb/1ml5888t.json', 'init=/tmp/tmpg1fephfb/itrwwij4.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modele9hdq8dv/prophet_model-20240709030846.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/upzgdopn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/fcsxxzn9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81004', 'data', 'file=/tmp/tmpg1fephfb/upzgdopn.json', 'init=/tmp/tmpg1fephfb/fcsxxzn9.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modely6hp233i/prophet_model-20240709030846.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/hoj89nto.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ou_p7aec.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86927', 'data', 'file=/tmp/tmpg1fephfb/hoj89nto.json', 'init=/tmp/tmpg1fephfb/ou_p7aec.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelmmttkh86/prophet_model-20240709030846.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/jw6ju7kn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/tvv0puda.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8896', 'data', 'file=/tmp/tmpg1fephfb/jw6ju7kn.json', 'init=/tmp/tmpg1fephfb/tvv0puda.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model3on7ela_/prophet_model-20240709030846.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/s2eyz9s9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/lm95wsqs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81865', 'data', 'file=/tmp/tmpg1fephfb/s2eyz9s9.json', 'init=/tmp/tmpg1fephfb/lm95wsqs.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model6petq2o2/prophet_model-20240709030847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/9m_hl11_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/sq4xwp1i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7931', 'data', 'file=/tmp/tmpg1fephfb/9m_hl11_.json', 'init=/tmp/tmpg1fephfb/sq4xwp1i.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelz28d31wf/prophet_model-20240709030847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ptdjguks.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/tjochv3n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43650', 'data', 'file=/tmp/tmpg1fephfb/ptdjguks.json', 'init=/tmp/tmpg1fephfb/tjochv3n.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelcv1zgve8/prophet_model-20240709030847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 6.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/mau_9e6x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/sntby8qj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76844', 'data', 'file=/tmp/tmpg1fephfb/mau_9e6x.json', 'init=/tmp/tmpg1fephfb/sntby8qj.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelknufcqqx/prophet_model-20240709030848.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/zgzocq73.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ypz7z2v8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15689', 'data', 'file=/tmp/tmpg1fephfb/zgzocq73.json', 'init=/tmp/tmpg1fephfb/ypz7z2v8.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelme31oagg/prophet_model-20240709030848.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/1ypdvmzl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/blj3jm9e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8798', 'data', 'file=/tmp/tmpg1fephfb/1ypdvmzl.json', 'init=/tmp/tmpg1fephfb/blj3jm9e.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelzocc8ppv/prophet_model-20240709030848.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/wdulzq77.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/z3peji0j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53495', 'data', 'file=/tmp/tmpg1fephfb/wdulzq77.json', 'init=/tmp/tmpg1fephfb/z3peji0j.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modeldhuqvl08/prophet_model-20240709030848.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 17.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/3_glgo55.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/3uk2b0v7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18264', 'data', 'file=/tmp/tmpg1fephfb/3_glgo55.json', 'init=/tmp/tmpg1fephfb/3uk2b0v7.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelsy291gkh/prophet_model-20240709030848.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/pw9mwub2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/yj5cpec3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6777', 'data', 'file=/tmp/tmpg1fephfb/pw9mwub2.json', 'init=/tmp/tmpg1fephfb/yj5cpec3.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_modelyjy7lu2l/prophet_model-20240709030849.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 03:08:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/ez33brzo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpg1fephfb/rcnsn8lv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28197', 'data', 'file=/tmp/tmpg1fephfb/ez33brzo.json', 'init=/tmp/tmpg1fephfb/rcnsn8lv.json', 'output', 'file=/tmp/tmpg1fephfb/prophet_model_tc28_ry/prophet_model-20240709030849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 03:08:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 03:08:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
results['is_weekend'] = results['is_weekend'].astype(int)
results['season'] = results['season'].astype(int)

results.head(15) # 정수로 표시되었는지 확인
# Out:
#    order_date product_category_name    demand  season  is_weekend
# 0  2019-09-01         fashion_shoes  1.310319       1           1
# 1  2019-09-02         fashion_shoes  1.232531       1           0
# 2  2019-09-03         fashion_shoes  1.527420       1           0
# 3  2019-09-04         fashion_shoes  1.178044       1           0
# 4  2019-09-05         fashion_shoes  1.480821       1           0
# 5  2019-09-06         fashion_shoes  1.405533       1           0
# 6  2019-09-07         fashion_shoes  1.242757       1           1
# 7  2019-09-08         fashion_shoes  1.307107       1           1
# 8  2019-09-09         fashion_shoes  1.229319       1           0
# 9  2019-09-10         fashion_shoes  1.524209       1           0
# 10 2019-09-11         fashion_shoes  1.174832       1           0
# 11 2019-09-12         fashion_shoes  1.477609       1           0
# 12 2019-09-13         fashion_shoes  1.402321       1           0
# 13 2019-09-14         fashion_shoes  1.239545       1           1
# 14 2019-09-15         fashion_shoes  1.303895       1           1

# %%
results_september = results.copy()
results_september.head()
# Out:
#   order_date product_category_name    demand  season  is_weekend
# 0 2019-09-01         fashion_shoes  1.310319       1           1
# 1 2019-09-02         fashion_shoes  1.232531       1           0
# 2 2019-09-03         fashion_shoes  1.527420       1           0
# 3 2019-09-04         fashion_shoes  1.178044       1           0
# 4 2019-09-05         fashion_shoes  1.480821       1           0

# %%
results_september.to_csv('results_september.csv', index=False)

# %%
category_demand_september = results_september.groupby('product_category_name')['demand'].sum().reset_index()

category_demand_september = category_demand_september.sort_values(by='demand', ascending=False)

top_5_categories = category_demand_september.head(10)

print("9월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:")
print(top_5_categories)
# Out:
# 9월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:
#    product_category_name      demand
# 38         health_beauty  786.283578
# 71         watches_gifts  614.033196
# 8         bed_bath_table  591.318865
# 44        home_utilities  506.626352
# 35       furniture_decor  463.066432
# 37          garden_tools  270.773206
# 6             automotive  242.297432
# 7                   baby  242.054481
# 64        sports_leisure  223.078903
# 59             perfumery  213.336913
