# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.25.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.0.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.53)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/ORDER_PROD_CUS_REV.csv", encoding='utf-8')
df.head()
# Out:
#       order_id  order_item_id order_purchase_timestamp    seller_id  \
# 0  ORDER_75477              1      2018-09-13 08:59:02  SELLER_0452
# 1  ORDER_63604              1      2018-04-26 10:53:06  SELLER_0414
# 2  ORDER_05566              1      2019-01-14 14:33:31  SELLER_1637
# 3  ORDER_04632              1      2018-02-04 13:57:51  SELLER_1445
# 4  ORDER_61452              1      2018-05-15 21:42:34  SELLER_0581
#
#     p_product_id product_category_name  price  freight_value     customer_id  \
# 0  PRODUCT_23128            cool_stuff   58.9          13.29  CUSTOMER_58023
# 1  PRODUCT_24351              pet_shop  239.9          19.93  CUSTOMER_30341
# 2  PRODUCT_20226       furniture_decor  199.0          17.87  CUSTOMER_30949
# 3  PRODUCT_07878          garden_tools  199.9          18.14  CUSTOMER_06713
# 4  PRODUCT_03505        home_utilities   21.9          12.69  CUSTOMER_20396
#
#   customer_state     review_id  review_score
# 0             RJ  REVIEW_45875             5
# 1             SP  REVIEW_24615             4
# 2             MG  REVIEW_03775             5
# 3             SP  REVIEW_49155             5
# 4             MG  REVIEW_20134             4

# %%
print(len(df))
# Out:
# 100415

# %%
df = df.drop(columns = ['order_item_id', 'p_product_id', 'customer_id', 'review_id'])
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score
# 0   58.9          13.29             RJ             5
# 1  239.9          19.93             SP             4
# 2  199.0          17.87             MG             5
# 3  199.9          18.14             SP             5
# 4   21.9          12.69             MG             4

# %%
# 범주 병합

category_mapping = {
    'agro_industry_and_commerce': 'agro_industry_and_commerce',
    'air_conditioning': 'air_conditioning',
    'arts': 'arts_and_crafts',
    'arts_and_crafts': 'arts_and_crafts',
    'audio': 'audio',
    'automotive': 'automotive',
    'baby': 'baby',
    'bed_bath_table': 'bed_bath_table',
    'bedroom_furniture': 'furniture',
    'blu_ray_dvds': 'blu_ray_dvds',
    'books_general_interest': 'books',
    'imported_books': 'books',
    'technical_books': 'books',
    'christmas_articles': 'christmas_articles',
    'cinema_photo': 'cinema_photo',
    'computers_accessories': 'computers_accessories',
    'consoles_games': 'consoles_games',
    'construction_tools': 'construction_tools',
    'construction_tools_construction': 'construction_tools',
    'construction_tools_garden': 'construction_tools',
    'construction_tools_lighting': 'construction_tools',
    'construction_tools_safety': 'construction_tools',
    'cool_stuff': 'cool_stuff',
    'diapers_hygiene': 'diapers_hygiene',
    'drinks': 'food_drinks',
    'food_drink': 'food_drinks',
    'electronics': 'electronics',
    'fashion_bags_accessories': 'fashion',
    'fashion_childrens_clothes': 'fashion',
    'fashion_mens_clothing': 'fashion',
    'fashion_shoes': 'fashion',
    'fashion_sport': 'fashion',
    'fashion_underwear_beachwear': 'fashion',
    'fashion_womens_clothing': 'fashion',
    'flowers': 'flowers',
    'food': 'food',
    'furniture_decor': 'furniture',
    'furniture_mattress_and_upholstery': 'furniture',
    'living_room_furniture': 'furniture',
    'office_furniture': 'furniture',
    'kitchen_laundry_room_dining_garden_furniture': 'furniture',
    'garden_tools': 'garden_tools',
    'health_beauty': 'health_beauty',
    'home_appliances': 'home_appliances',
    'home_appliances_2': 'home_appliances',
    'home_comfort': 'home_comfort',
    'home_comfort_2': 'home_comfort',
    'home_construction': 'home_construction',
    'home_utilities': 'home_utilities',
    'insurance_and_services': 'insurance_and_services',
    'landline_phones': 'landline_phones',
    'luggage_accessories': 'luggage_accessories',
    'marketplace': 'marketplace',
    'music': 'music',
    'musical_cds_dvds': 'music',
    'musical_instruments': 'music',
    'party_supplies': 'party_supplies',
    'pcs': 'pcs',
    'perfumery': 'perfumery',
    'pet_shop': 'pet_shop',
    'portable_home_oven_and_coffee': 'portable_home_oven_and_coffee',
    'signaling_and_security': 'signaling_and_security',
    'small_appliances': 'small_appliances',
    'sports_leisure': 'sports_leisure',
    'stationery': 'stationery',
    'tablets_printing_image': 'tablets_printing_image',
    'telephony': 'telephony',
    'the_kitchen': 'the_kitchen',
    'toys': 'toys',
    'watches_gifts': 'watches_gifts',
    'Unknown' : 'Unknown'
}

# %%
# 데이터 전처리
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_year'] = df['order_purchase_timestamp'].dt.year
df['order_month'] = df['order_purchase_timestamp'].dt.month
df['order_day'] = df['order_purchase_timestamp'].dt.day
df['order_hour'] = df['order_purchase_timestamp'].dt.hour

# %%
# 계절 정보를 컬럼으로 추가
# 봄 : 9, 10, 11, 여름 : 12, 1, 2, 가을 : 3, 4, 5, 겨울 : 6, 7, 8
def get_season(month):
    if month in [12, 1, 2]:
        return 'Summer'
    elif month in [3, 4, 5]:
        return 'Autumn'
    elif month in [6, 7, 8]:
        return 'Winter'
    else:
        return 'Spring'

df['season'] = df['order_month'].apply(get_season)
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score  order_year  order_month  \
# 0   58.9          13.29             RJ             5        2018            9
# 1  239.9          19.93             SP             4        2018            4
# 2  199.0          17.87             MG             5        2019            1
# 3  199.9          18.14             SP             5        2018            2
# 4   21.9          12.69             MG             4        2018            5
#
#    order_day  order_hour  season
# 0         13           8  Spring
# 1         26          10  Autumn
# 2         14          14  Summer
# 3          4          13  Summer
# 4         15          21  Autumn

# %%
df['order_date'] = df['order_purchase_timestamp'].dt.date
df['order_day_of_week'] = df['order_purchase_timestamp'].dt.dayofweek
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score  order_year  order_month  \
# 0   58.9          13.29             RJ             5        2018            9
# 1  239.9          19.93             SP             4        2018            4
# 2  199.0          17.87             MG             5        2019            1
# 3  199.9          18.14             SP             5        2018            2
# 4   21.9          12.69             MG             4        2018            5
#
#    order_day  order_hour  season  order_date  order_day_of_week
# 0         13           8  Spring  2018-09-13                  3
# 1         26          10  Autumn  2018-04-26                  3
# 2         14          14  Summer  2019-01-14                  0
# 3          4          13  Summer  2018-02-04                  6
# 4         15          21  Autumn  2018-05-15                  1

# %%
# 0: 주중, 1: 주말
df['is_weekend'] = df['order_purchase_timestamp'].dt.dayofweek.apply(lambda x: 1 if x >= 5 else 0)
df.head()
# Out:
#       order_id order_purchase_timestamp    seller_id product_category_name  \
# 0  ORDER_75477      2018-09-13 08:59:02  SELLER_0452            cool_stuff
# 1  ORDER_63604      2018-04-26 10:53:06  SELLER_0414              pet_shop
# 2  ORDER_05566      2019-01-14 14:33:31  SELLER_1637       furniture_decor
# 3  ORDER_04632      2018-02-04 13:57:51  SELLER_1445          garden_tools
# 4  ORDER_61452      2018-05-15 21:42:34  SELLER_0581        home_utilities
#
#    price  freight_value customer_state  review_score  order_year  order_month  \
# 0   58.9          13.29             RJ             5        2018            9
# 1  239.9          19.93             SP             4        2018            4
# 2  199.0          17.87             MG             5        2019            1
# 3  199.9          18.14             SP             5        2018            2
# 4   21.9          12.69             MG             4        2018            5
#
#    order_day  order_hour  season  order_date  order_day_of_week  is_weekend
# 0         13           8  Spring  2018-09-13                  3           0
# 1         26          10  Autumn  2018-04-26                  3           0
# 2         14          14  Summer  2019-01-14                  0           0
# 3          4          13  Summer  2018-02-04                  6           1
# 4         15          21  Autumn  2018-05-15                  1           0

# %%
df.describe()
# Out:
#             order_purchase_timestamp          price  freight_value  \
# count                         100415  100415.000000  100415.000000
# mean   2018-12-12 09:09:54.477388544     119.579557      19.750162
# min              2017-10-03 09:44:50       0.850000       0.000000
# 25%       2018-08-31 11:46:42.500000      39.900000      13.080000
# 50%              2019-01-03 17:20:23      74.900000      16.160000
# 75%              2019-04-08 22:31:35     133.000000      20.930000
# max              2019-07-30 13:26:53    6735.000000     409.680000
# std                              NaN     180.297001      15.332381
#
#         review_score     order_year    order_month      order_day  \
# count  100415.000000  100415.000000  100415.000000  100415.000000
# mean        4.069412    2018.501160       5.868944      15.591545
# min         1.000000    2017.000000       1.000000       1.000000
# 25%         4.000000    2018.000000       3.000000       8.000000
# 50%         5.000000    2019.000000       5.000000      16.000000
# 75%         5.000000    2019.000000       8.000000      23.000000
# max         5.000000    2019.000000      12.000000      31.000000
# std         1.355586       0.506236       3.332521       8.638727
#
#           order_hour  order_day_of_week     is_weekend
# count  100415.000000      100415.000000  100415.000000
# mean       14.755276           2.912892       0.251048
# min         0.000000           0.000000       0.000000
# 25%        11.000000           1.000000       0.000000
# 50%        15.000000           3.000000       0.000000
# 75%        19.000000           5.000000       1.000000
# max        23.000000           6.000000       1.000000
# std         5.321622           1.890327       0.433618

# %% [markdown]
# # 데이터 추출

# %%
practice_selected = ['order_date', 'product_category_name', 'season', 'is_weekend']
practice_df = df[practice_selected]
practice_df.head()
# Out:
#    order_date product_category_name  season  is_weekend
# 0  2018-09-13            cool_stuff  Spring           0
# 1  2018-04-26              pet_shop  Autumn           0
# 2  2019-01-14       furniture_decor  Summer           0
# 3  2018-02-04          garden_tools  Summer           1
# 4  2018-05-15        home_utilities  Autumn           0

# %%
# 'order_date' 컬럼을 datetime 형식으로 변환
practice_df['order_date'] = pd.to_datetime(practice_df['order_date'])

# 날짜별, 카테고리별로 count를 계산하여 'demand' 컬럼 추가
demand_df = practice_df.groupby(['order_date', 'product_category_name', 'season', 'is_weekend']).size().reset_index(name='demand')

demand_df.head(10)
# Out:
#   order_date product_category_name  season  is_weekend  demand
# 0 2017-10-03         fashion_shoes  Spring           0       1
# 1 2017-10-03       furniture_decor  Spring           0       2
# 2 2017-10-03        sports_leisure  Spring           0       3
# 3 2017-10-03                  toys  Spring           0       1
# 4 2017-10-03         watches_gifts  Spring           0       1
# 5 2017-10-04               Unknown  Spring           0       1
# 6 2017-10-04      air_conditioning  Spring           0       4
# 7 2017-10-04            automotive  Spring           0       1
# 8 2017-10-04                  baby  Spring           0       3
# 9 2017-10-04        bed_bath_table  Spring           0       2

# %%
print(len(demand_df))
# Out:
# 17461

# %% [markdown]
# # 7월 테스트셋 검증

# %%
import pandas as pd
from prophet import Prophet
from tqdm import tqdm

test_start_date = '2019-07-01'
test_end_date = '2019-07-31'

test_data = demand_df[(demand_df['order_date'] >= test_start_date) & (demand_df['order_date'] <= test_end_date)]

# 훈련 데이터셋에서 2019년 7월 데이터 제거
train_end_date = '2019-06-30'
demand_df_filtered = demand_df[demand_df['order_date'] <= train_end_date]

# 계절을 숫자로 매핑
def map_season(season):
    if season == 'Spring':
        return 1
    elif season == 'Summer':
        return 2
    elif season == 'Autumn':
        return 3
    elif season == 'Winter':
        return 4
    else:
        return 0  # 예외 처리

demand_df_filtered['season'] = demand_df_filtered['season'].apply(map_season)

def is_weekend(date):
    day_of_week = date.weekday()  # 0: 월요일, 6: 일요일
    return 1 if day_of_week >= 5 else 0  # 토요일(5), 일요일(6)은 주말로 처리

category_groups = demand_df_filtered.groupby('product_category_name')

results = pd.DataFrame()


for category, group in tqdm(category_groups, desc="Processing categories"):
    if category in test_data['product_category_name'].unique():  # 테스트 데이터셋에 해당 카테고리가 있는 경우에만 예측 수행

        group = group.rename(columns={'order_date': 'ds', 'demand': 'y', 'season': 'season', 'is_weekend': 'is_weekend'})
        group['is_weekend'] = group['ds'].apply(is_weekend)

        # Prophet 모델 생성 및 훈련 # 값이 크면 모델이 더 유연해지지만, 훈련 시간이 증가
        model = Prophet(growth ='linear',
                        n_changepoints = 25,
                        changepoint_range=0.8,
                        changepoint_prior_scale=0.05)

        # 계절 정보를 특성으로 추가
        model.add_regressor('season')
        model.add_regressor('is_weekend')

        model.fit(group[['ds', 'y', 'season', 'is_weekend']])

        future_dates = pd.date_range(start='2019-07-01', end='2019-07-31', freq='D')
        future = pd.DataFrame({'ds': future_dates})

        future['season'] = 4
        future['is_weekend'] = future['ds'].apply(is_weekend)

        forecast = model.predict(future)

        forecast['product_category_name'] = category
        forecast['order_date'] = forecast['ds']
        forecast['demand'] = forecast['yhat']
        results = pd.concat([results, forecast[['order_date', 'product_category_name','demand']]])
# Out:
# Processing categories:   0%|          | 0/72 [00:00<?, ?it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/v257ilq2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_i8q6h9o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30701', 'data', 'file=/tmp/tmptf6ftfrp/v257ilq2.json', 'init=/tmp/tmptf6ftfrp/_i8q6h9o.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelew5nxqqn/prophet_model-20240721125715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   1%|▏         | 1/72 [00:00<01:01,  1.16it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/34fheozw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/mbqc1vzi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45927', 'data', 'file=/tmp/tmptf6ftfrp/34fheozw.json', 'init=/tmp/tmptf6ftfrp/mbqc1vzi.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model30endbyx/prophet_model-20240721125716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   3%|▎         | 2/72 [00:01<00:49,  1.42it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/zjnbi6c0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/g9d51sb1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17882', 'data', 'file=/tmp/tmptf6ftfrp/zjnbi6c0.json', 'init=/tmp/tmptf6ftfrp/g9d51sb1.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelg94g815k/prophet_model-20240721125716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   4%|▍         | 3/72 [00:02<00:46,  1.47it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/et590pgo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vc23gujb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40227', 'data', 'file=/tmp/tmptf6ftfrp/et590pgo.json', 'init=/tmp/tmptf6ftfrp/vc23gujb.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelnca399o1/prophet_model-20240721125717.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   6%|▌         | 4/72 [00:02<00:50,  1.34it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 2.
# Processing categories:   7%|▋         | 5/72 [00:03<00:35,  1.87it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/x93axu2r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/75zuuymj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74038', 'data', 'file=/tmp/tmptf6ftfrp/x93axu2r.json', 'init=/tmp/tmptf6ftfrp/75zuuymj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model04ror_05/prophet_model-20240721125718.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:   8%|▊         | 6/72 [00:03<00:28,  2.31it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9svt5qjf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/mtprodz1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54730', 'data', 'file=/tmp/tmptf6ftfrp/9svt5qjf.json', 'init=/tmp/tmptf6ftfrp/mtprodz1.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelyr0yp0aw/prophet_model-20240721125718.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  10%|▉         | 7/72 [00:03<00:24,  2.66it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/chxn0xjl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/buw6vhlu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41270', 'data', 'file=/tmp/tmptf6ftfrp/chxn0xjl.json', 'init=/tmp/tmptf6ftfrp/buw6vhlu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model5rri2q1q/prophet_model-20240721125718.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  11%|█         | 8/72 [00:03<00:22,  2.90it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/f2y1yma8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9jsnne5n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83896', 'data', 'file=/tmp/tmptf6ftfrp/f2y1yma8.json', 'init=/tmp/tmptf6ftfrp/9jsnne5n.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelv1zzph8a/prophet_model-20240721125719.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  12%|█▎        | 9/72 [00:04<00:21,  2.96it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ryca7csr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ghp_iylw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55931', 'data', 'file=/tmp/tmptf6ftfrp/ryca7csr.json', 'init=/tmp/tmptf6ftfrp/ghp_iylw.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpx6ils_5/prophet_model-20240721125719.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  14%|█▍        | 10/72 [00:04<00:21,  2.93it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6elwtsgu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z8t4ws0h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25790', 'data', 'file=/tmp/tmptf6ftfrp/6elwtsgu.json', 'init=/tmp/tmptf6ftfrp/z8t4ws0h.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model1tk1yxer/prophet_model-20240721125719.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  15%|█▌        | 11/72 [00:04<00:21,  2.83it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8qqr_r4o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8w7t_vna.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93973', 'data', 'file=/tmp/tmptf6ftfrp/8qqr_r4o.json', 'init=/tmp/tmptf6ftfrp/8w7t_vna.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelfubpeh_t/prophet_model-20240721125720.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  17%|█▋        | 12/72 [00:05<00:17,  3.38it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/th0kyg8y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/4wohsjt_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18749', 'data', 'file=/tmp/tmptf6ftfrp/th0kyg8y.json', 'init=/tmp/tmptf6ftfrp/4wohsjt_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelrtgv61o7/prophet_model-20240721125720.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  18%|█▊        | 13/72 [00:05<00:17,  3.37it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/p370kuw4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/biguc_gp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35440', 'data', 'file=/tmp/tmptf6ftfrp/p370kuw4.json', 'init=/tmp/tmptf6ftfrp/biguc_gp.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelj2imafh7/prophet_model-20240721125720.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  19%|█▉        | 14/72 [00:05<00:15,  3.70it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/cj1pw1_a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3lcg8fcz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32', 'data', 'file=/tmp/tmptf6ftfrp/cj1pw1_a.json', 'init=/tmp/tmptf6ftfrp/3lcg8fcz.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpf3zcg2p/prophet_model-20240721125720.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  21%|██        | 15/72 [00:05<00:14,  3.81it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/htuj2zen.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9x_3jx0x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=673', 'data', 'file=/tmp/tmptf6ftfrp/htuj2zen.json', 'init=/tmp/tmptf6ftfrp/9x_3jx0x.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model2fkig4mh/prophet_model-20240721125721.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  22%|██▏       | 16/72 [00:06<00:13,  4.06it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/mnpp4amu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ujlmrz3k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92941', 'data', 'file=/tmp/tmptf6ftfrp/mnpp4amu.json', 'init=/tmp/tmptf6ftfrp/ujlmrz3k.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model3v0utlzd/prophet_model-20240721125721.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  24%|██▎       | 17/72 [00:06<00:13,  4.11it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/b9uqnhkj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/kycswnr1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55199', 'data', 'file=/tmp/tmptf6ftfrp/b9uqnhkj.json', 'init=/tmp/tmptf6ftfrp/kycswnr1.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model4t3zidqg/prophet_model-20240721125721.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  25%|██▌       | 18/72 [00:06<00:11,  4.57it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/a_1r0o3k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/w77iadh_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54927', 'data', 'file=/tmp/tmptf6ftfrp/a_1r0o3k.json', 'init=/tmp/tmptf6ftfrp/w77iadh_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelyuv288km/prophet_model-20240721125721.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  26%|██▋       | 19/72 [00:06<00:10,  5.03it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z6ghaol4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/p4arun2m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10312', 'data', 'file=/tmp/tmptf6ftfrp/z6ghaol4.json', 'init=/tmp/tmptf6ftfrp/p4arun2m.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_objru56/prophet_model-20240721125721.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  28%|██▊       | 20/72 [00:06<00:12,  4.33it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/zivfbez_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_96pm6m9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90128', 'data', 'file=/tmp/tmptf6ftfrp/zivfbez_.json', 'init=/tmp/tmptf6ftfrp/_96pm6m9.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0nqpomhr/prophet_model-20240721125722.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  29%|██▉       | 21/72 [00:07<00:12,  3.93it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/pe1hlepe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/2x3l3nla.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47143', 'data', 'file=/tmp/tmptf6ftfrp/pe1hlepe.json', 'init=/tmp/tmptf6ftfrp/2x3l3nla.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelms0hwv2_/prophet_model-20240721125722.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  31%|███       | 22/72 [00:07<00:11,  4.27it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 14.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ufsybcjq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/pk2hgv29.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77008', 'data', 'file=/tmp/tmptf6ftfrp/ufsybcjq.json', 'init=/tmp/tmptf6ftfrp/pk2hgv29.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelxa4s3u32/prophet_model-20240721125722.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  32%|███▏      | 23/72 [00:07<00:10,  4.56it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/bnhh69o4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/gm10ralq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86282', 'data', 'file=/tmp/tmptf6ftfrp/bnhh69o4.json', 'init=/tmp/tmptf6ftfrp/gm10ralq.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelrxepocqn/prophet_model-20240721125722.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  33%|███▎      | 24/72 [00:07<00:09,  4.83it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/nt6y_5lc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wudgimac.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48121', 'data', 'file=/tmp/tmptf6ftfrp/nt6y_5lc.json', 'init=/tmp/tmptf6ftfrp/wudgimac.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpbban50i/prophet_model-20240721125722.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  35%|███▍      | 25/72 [00:07<00:09,  4.77it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/oloq64tk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/nqkmh7pf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20460', 'data', 'file=/tmp/tmptf6ftfrp/oloq64tk.json', 'init=/tmp/tmptf6ftfrp/nqkmh7pf.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelrerxhoet/prophet_model-20240721125723.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  36%|███▌      | 26/72 [00:08<00:09,  4.94it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ihyyhxmg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/12n3hvev.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50282', 'data', 'file=/tmp/tmptf6ftfrp/ihyyhxmg.json', 'init=/tmp/tmptf6ftfrp/12n3hvev.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeltpgbqalx/prophet_model-20240721125723.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  39%|███▉      | 28/72 [00:08<00:07,  5.50it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/d9cblj72.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/053e_qsj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22334', 'data', 'file=/tmp/tmptf6ftfrp/d9cblj72.json', 'init=/tmp/tmptf6ftfrp/053e_qsj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelrqe_wo9m/prophet_model-20240721125723.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  40%|████      | 29/72 [00:08<00:07,  5.69it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/4mwaku24.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/isc9uxvp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45452', 'data', 'file=/tmp/tmptf6ftfrp/4mwaku24.json', 'init=/tmp/tmptf6ftfrp/isc9uxvp.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelbvevgodp/prophet_model-20240721125723.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  43%|████▎     | 31/72 [00:08<00:05,  7.14it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 18.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/a3eb36h5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/lq99ppnk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51192', 'data', 'file=/tmp/tmptf6ftfrp/a3eb36h5.json', 'init=/tmp/tmptf6ftfrp/lq99ppnk.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelufnln3wr/prophet_model-20240721125724.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  46%|████▌     | 33/72 [00:09<00:05,  7.66it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3ou1g_zl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/88g6w0pv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26313', 'data', 'file=/tmp/tmptf6ftfrp/3ou1g_zl.json', 'init=/tmp/tmptf6ftfrp/88g6w0pv.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelag6jf1oq/prophet_model-20240721125724.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  47%|████▋     | 34/72 [00:09<00:05,  7.20it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/saje1424.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7bhrgro2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31784', 'data', 'file=/tmp/tmptf6ftfrp/saje1424.json', 'init=/tmp/tmptf6ftfrp/7bhrgro2.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldjkmo4_r/prophet_model-20240721125724.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  49%|████▊     | 35/72 [00:09<00:05,  6.97it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ux7718qd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7r5r93f_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38136', 'data', 'file=/tmp/tmptf6ftfrp/ux7718qd.json', 'init=/tmp/tmptf6ftfrp/7r5r93f_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model28yrl55c/prophet_model-20240721125724.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  50%|█████     | 36/72 [00:09<00:05,  6.48it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ihunvv_a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/yl3bq3cr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45817', 'data', 'file=/tmp/tmptf6ftfrp/ihunvv_a.json', 'init=/tmp/tmptf6ftfrp/yl3bq3cr.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelitvx15q6/prophet_model-20240721125724.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  51%|█████▏    | 37/72 [00:09<00:06,  5.57it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/bi70945g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/jigtw0ds.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94310', 'data', 'file=/tmp/tmptf6ftfrp/bi70945g.json', 'init=/tmp/tmptf6ftfrp/jigtw0ds.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelit9haxxn/prophet_model-20240721125725.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  53%|█████▎    | 38/72 [00:10<00:06,  5.29it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/mdgruk7r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ix9c2268.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61485', 'data', 'file=/tmp/tmptf6ftfrp/mdgruk7r.json', 'init=/tmp/tmptf6ftfrp/ix9c2268.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelfkxftn76/prophet_model-20240721125725.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  54%|█████▍    | 39/72 [00:10<00:06,  5.25it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1p5k5hrr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/f9p68i2u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76739', 'data', 'file=/tmp/tmptf6ftfrp/1p5k5hrr.json', 'init=/tmp/tmptf6ftfrp/f9p68i2u.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model7adsfjho/prophet_model-20240721125725.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  56%|█████▌    | 40/72 [00:10<00:05,  5.49it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/f14qz5w9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0izstp80.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71521', 'data', 'file=/tmp/tmptf6ftfrp/f14qz5w9.json', 'init=/tmp/tmptf6ftfrp/0izstp80.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelq97ltmyf/prophet_model-20240721125725.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  57%|█████▋    | 41/72 [00:10<00:05,  5.66it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/br6id8tj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0vh3342e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90851', 'data', 'file=/tmp/tmptf6ftfrp/br6id8tj.json', 'init=/tmp/tmptf6ftfrp/0vh3342e.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelc6upbyac/prophet_model-20240721125725.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  58%|█████▊    | 42/72 [00:10<00:05,  5.50it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8mwtnbg4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wrkguve7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59982', 'data', 'file=/tmp/tmptf6ftfrp/8mwtnbg4.json', 'init=/tmp/tmptf6ftfrp/wrkguve7.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelk1ivfhy_/prophet_model-20240721125725.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  60%|█████▉    | 43/72 [00:10<00:05,  5.01it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/klwqbox3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1390y_ua.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62879', 'data', 'file=/tmp/tmptf6ftfrp/klwqbox3.json', 'init=/tmp/tmptf6ftfrp/1390y_ua.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model6g43mzt9/prophet_model-20240721125726.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  61%|██████    | 44/72 [00:11<00:05,  5.10it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/41jg7y6o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/q7gii1if.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48768', 'data', 'file=/tmp/tmptf6ftfrp/41jg7y6o.json', 'init=/tmp/tmptf6ftfrp/q7gii1if.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeltvevhzkk/prophet_model-20240721125726.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  62%|██████▎   | 45/72 [00:11<00:05,  5.04it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/r1cyyb44.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/fhmzmnp5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72620', 'data', 'file=/tmp/tmptf6ftfrp/r1cyyb44.json', 'init=/tmp/tmptf6ftfrp/fhmzmnp5.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelqjhugw85/prophet_model-20240721125726.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  64%|██████▍   | 46/72 [00:11<00:05,  4.95it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6r5_52v6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/t9l594cu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19780', 'data', 'file=/tmp/tmptf6ftfrp/6r5_52v6.json', 'init=/tmp/tmptf6ftfrp/t9l594cu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelsf797sfy/prophet_model-20240721125726.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  65%|██████▌   | 47/72 [00:11<00:04,  5.08it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/bti0_vnn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ux83g6gc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49666', 'data', 'file=/tmp/tmptf6ftfrp/bti0_vnn.json', 'init=/tmp/tmptf6ftfrp/ux83g6gc.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelcp63pl53/prophet_model-20240721125726.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  68%|██████▊   | 49/72 [00:11<00:03,  6.57it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/xzre3rjy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3dgmi32q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82094', 'data', 'file=/tmp/tmptf6ftfrp/xzre3rjy.json', 'init=/tmp/tmptf6ftfrp/3dgmi32q.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelyaadgucb/prophet_model-20240721125727.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  69%|██████▉   | 50/72 [00:12<00:03,  6.49it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/v82_sp_0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8e5ie7vf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21536', 'data', 'file=/tmp/tmptf6ftfrp/v82_sp_0.json', 'init=/tmp/tmptf6ftfrp/8e5ie7vf.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelhta2g8hw/prophet_model-20240721125727.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...
# 12:57:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  75%|███████▌  | 54/72 [00:13<00:03,  4.55it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/eez2hkel.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/30r56em6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25847', 'data', 'file=/tmp/tmptf6ftfrp/eez2hkel.json', 'init=/tmp/tmptf6ftfrp/30r56em6.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelfaj87nx4/prophet_model-20240721125728.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  78%|███████▊  | 56/72 [00:13<00:02,  6.29it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_v2m21_6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/thi0wrbt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87681', 'data', 'file=/tmp/tmptf6ftfrp/_v2m21_6.json', 'init=/tmp/tmptf6ftfrp/thi0wrbt.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model2xqj85qr/prophet_model-20240721125728.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  79%|███████▉  | 57/72 [00:13<00:02,  6.11it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0dlc51i8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/yslz3puh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91713', 'data', 'file=/tmp/tmptf6ftfrp/0dlc51i8.json', 'init=/tmp/tmptf6ftfrp/yslz3puh.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modell5i41mtw/prophet_model-20240721125728.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  81%|████████  | 58/72 [00:13<00:03,  4.12it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/nk6yy3f0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/k3u5ou7m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8552', 'data', 'file=/tmp/tmptf6ftfrp/nk6yy3f0.json', 'init=/tmp/tmptf6ftfrp/k3u5ou7m.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelfs_71sn4/prophet_model-20240721125729.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  82%|████████▏ | 59/72 [00:14<00:03,  3.62it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/67pvg_dc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9tya5tfx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22262', 'data', 'file=/tmp/tmptf6ftfrp/67pvg_dc.json', 'init=/tmp/tmptf6ftfrp/9tya5tfx.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model8ezm0vtr/prophet_model-20240721125729.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  83%|████████▎ | 60/72 [00:14<00:03,  3.58it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/aj_25ls6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3yql94e_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68220', 'data', 'file=/tmp/tmptf6ftfrp/aj_25ls6.json', 'init=/tmp/tmptf6ftfrp/3yql94e_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeluurinlyz/prophet_model-20240721125729.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  85%|████████▍ | 61/72 [00:14<00:03,  3.58it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/lay9pl9i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6iyqxiuj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44329', 'data', 'file=/tmp/tmptf6ftfrp/lay9pl9i.json', 'init=/tmp/tmptf6ftfrp/6iyqxiuj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model9gugj3m9/prophet_model-20240721125729.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  86%|████████▌ | 62/72 [00:15<00:02,  3.48it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/123dvnty.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/zgcmjezr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60708', 'data', 'file=/tmp/tmptf6ftfrp/123dvnty.json', 'init=/tmp/tmptf6ftfrp/zgcmjezr.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model1j90lq_2/prophet_model-20240721125730.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:57:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  88%|████████▊ | 63/72 [00:15<00:02,  3.08it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ehfovc5g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/jrnxi810.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93953', 'data', 'file=/tmp/tmptf6ftfrp/ehfovc5g.json', 'init=/tmp/tmptf6ftfrp/jrnxi810.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeli5obq8vz/prophet_model-20240721125730.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  89%|████████▉ | 64/72 [00:15<00:02,  3.36it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hnl0u4cz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/r_fs9vec.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79995', 'data', 'file=/tmp/tmptf6ftfrp/hnl0u4cz.json', 'init=/tmp/tmptf6ftfrp/r_fs9vec.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelek766vz_/prophet_model-20240721125730.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  90%|█████████ | 65/72 [00:16<00:02,  3.26it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vy6roeu1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rj63hdiq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17077', 'data', 'file=/tmp/tmptf6ftfrp/vy6roeu1.json', 'init=/tmp/tmptf6ftfrp/rj63hdiq.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_models5qc__2l/prophet_model-20240721125731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  92%|█████████▏| 66/72 [00:16<00:01,  3.21it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/v1olxhzl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_gajcuw8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58303', 'data', 'file=/tmp/tmptf6ftfrp/v1olxhzl.json', 'init=/tmp/tmptf6ftfrp/_gajcuw8.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmyqhm0fk/prophet_model-20240721125731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  94%|█████████▍| 68/72 [00:16<00:00,  4.49it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/yqw7pnpw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/5ek73_91.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59257', 'data', 'file=/tmp/tmptf6ftfrp/yqw7pnpw.json', 'init=/tmp/tmptf6ftfrp/5ek73_91.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_qbh5ye3/prophet_model-20240721125731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  96%|█████████▌| 69/72 [00:16<00:00,  3.98it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dj1um2ls.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ma661hb4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67772', 'data', 'file=/tmp/tmptf6ftfrp/dj1um2ls.json', 'init=/tmp/tmptf6ftfrp/ma661hb4.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modellumos130/prophet_model-20240721125732.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories:  99%|█████████▊| 71/72 [00:17<00:00,  4.73it/s]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3uyo2h6s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/pg424si7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76223', 'data', 'file=/tmp/tmptf6ftfrp/3uyo2h6s.json', 'init=/tmp/tmptf6ftfrp/pg424si7.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelsx_8t9fb/prophet_model-20240721125732.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 12:57:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:57:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Processing categories: 100%|██████████| 72/72 [00:17<00:00,  4.10it/s]

# %%
print(len(results))
results.tail()
# Out:
# 2015
#    order_date product_category_name     demand
# 26 2019-07-27         watches_gifts  18.574814
# 27 2019-07-28         watches_gifts  15.982368
# 28 2019-07-29         watches_gifts  16.857763
# 29 2019-07-30         watches_gifts  19.538880
# 30 2019-07-31         watches_gifts  18.814422

# %%
# 모든 날짜와 카테고리의 조합 생성
all_dates = pd.date_range(start=test_start_date, end=test_end_date, freq='D')
all_categories = test_data['product_category_name'].unique()
all_combinations = pd.MultiIndex.from_product([all_dates, all_categories], names=['order_date', 'product_category_name']).to_frame(index=False)

# 예측 결과와 실제 데이터를 모든 조합에 맞게 병합
results = pd.merge(all_combinations, results, on=['order_date', 'product_category_name'], how='left')
test_data = pd.merge(all_combinations, test_data, on=['order_date', 'product_category_name'], how='left')

# 결과와 실제 데이터 합치기
merged_results = pd.merge(results, test_data, on=['order_date', 'product_category_name'], how='inner')

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score, mean_squared_error

# NaN을 0으로 대체한 후 계산
mae = mean_absolute_error(merged_results['demand_x'].fillna(0), merged_results['demand_y'].fillna(0))
r2 = r2_score(merged_results['demand_x'].fillna(0), merged_results['demand_y'].fillna(0))
rmse = mean_squared_error(merged_results['demand_x'].fillna(0), merged_results['demand_y'].fillna(0), squared=False)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2) Score: {r2}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 2.496000502224008
# R-squared (R2) Score: 0.48385077702458634
# Root Mean Squared Error (RMSE): 4.171865956641915

# %%
# 전체 테스트 데이터에 대한 기술 통계량 계산
test_data_stats = test_data['demand'].describe()
predicted_stats = results['demand'].describe()

print("\nActual Demand Statistics (Overall):")
print(test_data_stats)

print("\nPredicted Demand Statistics (Overall):")
print(predicted_stats)
# Out:
# Actual Demand Statistics (Overall):
# count    920.000000
# mean       5.055435
# std        5.919865
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        7.000000
# max       40.000000
# Name: demand, dtype: float64
#
# Predicted Demand Statistics (Overall):
# count    2015.000000
# mean        4.376281
# std         5.808320
# min        -0.378560
# 25%         1.361687
# 50%         1.935923
# 75%         4.589450
# max        30.441519
# Name: demand, dtype: float64

# %% [markdown]
# # 8월 데이터셋에 모델 적용 & 예측

# %%
# 8월 데이터셋 계절 정보

def get_season(month):
    if month in [12, 1, 2]:
        return 2  # Summer
    elif month in [3, 4, 5]:
        return 3  # Autumn
    elif month in [6, 7, 8]:
        return 4  # Winter
    else:
        return 1  # Spring

demand_df['season'] = demand_df['order_date'].dt.month.apply(get_season)

dates = pd.date_range(start='2019-08-01', end='2019-08-31', freq='D')

date_list = []

for date in dates:
    date_list.append({'date': date})

X_august = pd.DataFrame(date_list)
X_august['product_category_name'] = ''
X_august['is_weekend'] = X_august['date'].apply(lambda x: 1 if x.weekday() >= 5 else 0)
X_august['season'] = X_august['date'].dt.month.apply(get_season)

results = pd.DataFrame()

for category in demand_df['product_category_name'].unique():
    group = demand_df[demand_df['product_category_name'] == category]

    if not group.empty:

        group = group.rename(columns={'order_date': 'ds', 'demand': 'y', 'season': 'season', 'is_weekend': 'is_weekend'})

        model = Prophet()

        model.add_regressor('season')
        model.add_regressor('is_weekend')

        model.fit(group[['ds', 'y', 'season', 'is_weekend']])

        # 2019년 8월 1일부터 31일까지의 날짜 복사
        future = X_august.copy()
        future = future.rename(columns={'date': 'ds'})

        forecast = model.predict(future[['ds', 'season', 'is_weekend']])

        forecast['season'] = future['season'].values
        forecast['is_weekend'] = future['is_weekend'].values

        # 결과 저장  # 주말여부 및 계절 정보 함께 출력 -- 분석에 사용
        forecast['product_category_name'] = category
        forecast['order_date'] = forecast['ds']
        forecast['demand'] = forecast['yhat']
        results = pd.concat([results, forecast[['order_date', 'product_category_name', 'season', 'is_weekend', 'demand']]])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/xv04j5ro.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/heuyufud.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8844', 'data', 'file=/tmp/tmptf6ftfrp/xv04j5ro.json', 'init=/tmp/tmptf6ftfrp/heuyufud.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model1v9r_axv/prophet_model-20240721141004.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/2l67at9b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vuukusgh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6110', 'data', 'file=/tmp/tmptf6ftfrp/2l67at9b.json', 'init=/tmp/tmptf6ftfrp/vuukusgh.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmwoyj0dl/prophet_model-20240721141005.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/pl_w9rkg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/507j5296.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67233', 'data', 'file=/tmp/tmptf6ftfrp/pl_w9rkg.json', 'init=/tmp/tmptf6ftfrp/507j5296.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model08828yyl/prophet_model-20240721141005.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/sk1xwaek.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_ht89g6y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52870', 'data', 'file=/tmp/tmptf6ftfrp/sk1xwaek.json', 'init=/tmp/tmptf6ftfrp/_ht89g6y.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model7rxcb5rl/prophet_model-20240721141005.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/fsy6k2es.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/__ybvkn6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60692', 'data', 'file=/tmp/tmptf6ftfrp/fsy6k2es.json', 'init=/tmp/tmptf6ftfrp/__ybvkn6.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeld55ghiwi/prophet_model-20240721141005.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wz6jkkyr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ny04wmp0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44561', 'data', 'file=/tmp/tmptf6ftfrp/wz6jkkyr.json', 'init=/tmp/tmptf6ftfrp/ny04wmp0.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelkh28txc8/prophet_model-20240721141006.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rxmuv6j1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/x5mhjlvo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23683', 'data', 'file=/tmp/tmptf6ftfrp/rxmuv6j1.json', 'init=/tmp/tmptf6ftfrp/x5mhjlvo.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelp80cntcm/prophet_model-20240721141006.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/azui0p5j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/l_bjhu0r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29988', 'data', 'file=/tmp/tmptf6ftfrp/azui0p5j.json', 'init=/tmp/tmptf6ftfrp/l_bjhu0r.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelz5zc8m0p/prophet_model-20240721141007.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rrtg21g4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/b7d3enx4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40065', 'data', 'file=/tmp/tmptf6ftfrp/rrtg21g4.json', 'init=/tmp/tmptf6ftfrp/b7d3enx4.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelatpi4kfa/prophet_model-20240721141007.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/lhuek06l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z8ni334y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71728', 'data', 'file=/tmp/tmptf6ftfrp/lhuek06l.json', 'init=/tmp/tmptf6ftfrp/z8ni334y.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0wh13_80/prophet_model-20240721141008.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/p54phf38.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/m3y2s_qd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43071', 'data', 'file=/tmp/tmptf6ftfrp/p54phf38.json', 'init=/tmp/tmptf6ftfrp/m3y2s_qd.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelkkk7zlq2/prophet_model-20240721141009.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/imce7tx0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/q2lhp3kr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91219', 'data', 'file=/tmp/tmptf6ftfrp/imce7tx0.json', 'init=/tmp/tmptf6ftfrp/q2lhp3kr.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model3ci02jpz/prophet_model-20240721141009.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/22bxi7c0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/eiiixxal.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27732', 'data', 'file=/tmp/tmptf6ftfrp/22bxi7c0.json', 'init=/tmp/tmptf6ftfrp/eiiixxal.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmu9_89li/prophet_model-20240721141010.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/kwi0l7c8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/drfrstld.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24110', 'data', 'file=/tmp/tmptf6ftfrp/kwi0l7c8.json', 'init=/tmp/tmptf6ftfrp/drfrstld.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelvaj2i5k4/prophet_model-20240721141010.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/zl87pzfx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vd3lf2jb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98687', 'data', 'file=/tmp/tmptf6ftfrp/zl87pzfx.json', 'init=/tmp/tmptf6ftfrp/vd3lf2jb.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmcl3td7s/prophet_model-20240721141011.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/xyyumxpt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/pcqw6325.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14540', 'data', 'file=/tmp/tmptf6ftfrp/xyyumxpt.json', 'init=/tmp/tmptf6ftfrp/pcqw6325.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelng6j87j9/prophet_model-20240721141011.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rl7fkvpu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/tuf2zddu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29116', 'data', 'file=/tmp/tmptf6ftfrp/rl7fkvpu.json', 'init=/tmp/tmptf6ftfrp/tuf2zddu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model05vmm3h7/prophet_model-20240721141012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/tb0198fc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/cl5by2mb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57973', 'data', 'file=/tmp/tmptf6ftfrp/tb0198fc.json', 'init=/tmp/tmptf6ftfrp/cl5by2mb.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpdz69m1m/prophet_model-20240721141012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/06p9ibm8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/tga2mpra.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35680', 'data', 'file=/tmp/tmptf6ftfrp/06p9ibm8.json', 'init=/tmp/tmptf6ftfrp/tga2mpra.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model616ogtzk/prophet_model-20240721141012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wcuvr8w_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/5lebvxs7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63354', 'data', 'file=/tmp/tmptf6ftfrp/wcuvr8w_.json', 'init=/tmp/tmptf6ftfrp/5lebvxs7.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelj3uhxad_/prophet_model-20240721141013.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/iv7yd2hi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9nda1led.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11083', 'data', 'file=/tmp/tmptf6ftfrp/iv7yd2hi.json', 'init=/tmp/tmptf6ftfrp/9nda1led.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model9u6ocyuu/prophet_model-20240721141013.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/bz_di7_9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/58eks46k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65557', 'data', 'file=/tmp/tmptf6ftfrp/bz_di7_9.json', 'init=/tmp/tmptf6ftfrp/58eks46k.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelb_yszux6/prophet_model-20240721141014.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/nfgbgj69.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/l9er0mfj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97894', 'data', 'file=/tmp/tmptf6ftfrp/nfgbgj69.json', 'init=/tmp/tmptf6ftfrp/l9er0mfj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeloap5h030/prophet_model-20240721141014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wmko_jb3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/v16jakyk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52305', 'data', 'file=/tmp/tmptf6ftfrp/wmko_jb3.json', 'init=/tmp/tmptf6ftfrp/v16jakyk.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_obqjin6/prophet_model-20240721141015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8xsik3d2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z47mdesz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75856', 'data', 'file=/tmp/tmptf6ftfrp/8xsik3d2.json', 'init=/tmp/tmptf6ftfrp/z47mdesz.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelvsuqusmn/prophet_model-20240721141015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/fyy63ajv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ph47neck.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31496', 'data', 'file=/tmp/tmptf6ftfrp/fyy63ajv.json', 'init=/tmp/tmptf6ftfrp/ph47neck.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model9jp8zk8m/prophet_model-20240721141015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/stzwarqn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/kw6uyeji.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2327', 'data', 'file=/tmp/tmptf6ftfrp/stzwarqn.json', 'init=/tmp/tmptf6ftfrp/kw6uyeji.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_upx0mog/prophet_model-20240721141016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hjct7ys1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/2k6ushw8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2576', 'data', 'file=/tmp/tmptf6ftfrp/hjct7ys1.json', 'init=/tmp/tmptf6ftfrp/2k6ushw8.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_aldclxh/prophet_model-20240721141016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/isx9vxva.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hmk7s1nu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94792', 'data', 'file=/tmp/tmptf6ftfrp/isx9vxva.json', 'init=/tmp/tmptf6ftfrp/hmk7s1nu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelf8idp59p/prophet_model-20240721141017.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/oq09x_nr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z5kefxsa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54161', 'data', 'file=/tmp/tmptf6ftfrp/oq09x_nr.json', 'init=/tmp/tmptf6ftfrp/z5kefxsa.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model7p5q63db/prophet_model-20240721141017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/f4himoih.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0r469f8c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4584', 'data', 'file=/tmp/tmptf6ftfrp/f4himoih.json', 'init=/tmp/tmptf6ftfrp/0r469f8c.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpih8bc17/prophet_model-20240721141018.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0os8g01j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/n7rh2f9f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55505', 'data', 'file=/tmp/tmptf6ftfrp/0os8g01j.json', 'init=/tmp/tmptf6ftfrp/n7rh2f9f.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modela48g3hqp/prophet_model-20240721141019.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7bzwxur9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/86zef8iu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45598', 'data', 'file=/tmp/tmptf6ftfrp/7bzwxur9.json', 'init=/tmp/tmptf6ftfrp/86zef8iu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modely2zo2_uk/prophet_model-20240721141019.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/391kiqbd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_tokngnu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46256', 'data', 'file=/tmp/tmptf6ftfrp/391kiqbd.json', 'init=/tmp/tmptf6ftfrp/_tokngnu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelelk8mhao/prophet_model-20240721141020.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/qo59wx48.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/agimikfy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35235', 'data', 'file=/tmp/tmptf6ftfrp/qo59wx48.json', 'init=/tmp/tmptf6ftfrp/agimikfy.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelwp36t1xw/prophet_model-20240721141020.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/m_4xdyei.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/xo71_88e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96621', 'data', 'file=/tmp/tmptf6ftfrp/m_4xdyei.json', 'init=/tmp/tmptf6ftfrp/xo71_88e.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelclqhhcox/prophet_model-20240721141020.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9fzbmwtu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/e__v6s9y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48383', 'data', 'file=/tmp/tmptf6ftfrp/9fzbmwtu.json', 'init=/tmp/tmptf6ftfrp/e__v6s9y.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelssdqmuk_/prophet_model-20240721141020.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/96p1v2vd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7te08gx8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59769', 'data', 'file=/tmp/tmptf6ftfrp/96p1v2vd.json', 'init=/tmp/tmptf6ftfrp/7te08gx8.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelgdtp1m2p/prophet_model-20240721141020.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 0.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rkp1wjv7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/jgnvayep.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89192', 'data', 'file=/tmp/tmptf6ftfrp/rkp1wjv7.json', 'init=/tmp/tmptf6ftfrp/jgnvayep.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeljmxmoz52/prophet_model-20240721141021.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/mql5ooz2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/gv14ttdk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98092', 'data', 'file=/tmp/tmptf6ftfrp/mql5ooz2.json', 'init=/tmp/tmptf6ftfrp/gv14ttdk.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_vpzyh_e/prophet_model-20240721141021.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/gwoaq0b1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_xwondem.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63638', 'data', 'file=/tmp/tmptf6ftfrp/gwoaq0b1.json', 'init=/tmp/tmptf6ftfrp/_xwondem.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmqxejgiy/prophet_model-20240721141021.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/300sowec.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3nbdkaoy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29165', 'data', 'file=/tmp/tmptf6ftfrp/300sowec.json', 'init=/tmp/tmptf6ftfrp/3nbdkaoy.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelu02nd7in/prophet_model-20240721141021.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ke6u085l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/a2p7sh6h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4304', 'data', 'file=/tmp/tmptf6ftfrp/ke6u085l.json', 'init=/tmp/tmptf6ftfrp/a2p7sh6h.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0klwj3c8/prophet_model-20240721141022.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/f7qsbw0t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3i7l9_5m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90641', 'data', 'file=/tmp/tmptf6ftfrp/f7qsbw0t.json', 'init=/tmp/tmptf6ftfrp/3i7l9_5m.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelych5f0te/prophet_model-20240721141022.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wlug15ja.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rj2obne1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51158', 'data', 'file=/tmp/tmptf6ftfrp/wlug15ja.json', 'init=/tmp/tmptf6ftfrp/rj2obne1.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpbd8umcs/prophet_model-20240721141022.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0zemva1j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/digqu918.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58898', 'data', 'file=/tmp/tmptf6ftfrp/0zemva1j.json', 'init=/tmp/tmptf6ftfrp/digqu918.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model16giydwg/prophet_model-20240721141023.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0xzgr7af.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6lp4p250.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26793', 'data', 'file=/tmp/tmptf6ftfrp/0xzgr7af.json', 'init=/tmp/tmptf6ftfrp/6lp4p250.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelsfmc7v16/prophet_model-20240721141023.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/09kkmm_r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/bsaz6lqs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62636', 'data', 'file=/tmp/tmptf6ftfrp/09kkmm_r.json', 'init=/tmp/tmptf6ftfrp/bsaz6lqs.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelijiq77fo/prophet_model-20240721141024.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8udm1ih9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ht83_kxn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14817', 'data', 'file=/tmp/tmptf6ftfrp/8udm1ih9.json', 'init=/tmp/tmptf6ftfrp/ht83_kxn.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeljvzg6lqy/prophet_model-20240721141024.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/fj4k0qr8.json
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/r6wv36jj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/xnn48z_y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90699', 'data', 'file=/tmp/tmptf6ftfrp/r6wv36jj.json', 'init=/tmp/tmptf6ftfrp/xnn48z_y.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeltyabw8ft/prophet_model-20240721141025.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/votv1olj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hyv35afj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63498', 'data', 'file=/tmp/tmptf6ftfrp/votv1olj.json', 'init=/tmp/tmptf6ftfrp/hyv35afj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldju9h03l/prophet_model-20240721141025.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/71ldqhau.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/72o86d4l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36276', 'data', 'file=/tmp/tmptf6ftfrp/71ldqhau.json', 'init=/tmp/tmptf6ftfrp/72o86d4l.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelhn_s5nab/prophet_model-20240721141026.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/984ho4iu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/l7fi4n1y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81401', 'data', 'file=/tmp/tmptf6ftfrp/984ho4iu.json', 'init=/tmp/tmptf6ftfrp/l7fi4n1y.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_9muhjp7/prophet_model-20240721141026.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3wq79xj0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wdpt38go.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18148', 'data', 'file=/tmp/tmptf6ftfrp/3wq79xj0.json', 'init=/tmp/tmptf6ftfrp/wdpt38go.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0czze811/prophet_model-20240721141026.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/kprl2p5b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/39ea0hri.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85957', 'data', 'file=/tmp/tmptf6ftfrp/kprl2p5b.json', 'init=/tmp/tmptf6ftfrp/39ea0hri.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelkv5c4w_t/prophet_model-20240721141026.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/padclu0d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dvhn6svj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7418', 'data', 'file=/tmp/tmptf6ftfrp/padclu0d.json', 'init=/tmp/tmptf6ftfrp/dvhn6svj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelp8l8qm0b/prophet_model-20240721141027.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/w79ui7vt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/conxhq3w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49018', 'data', 'file=/tmp/tmptf6ftfrp/w79ui7vt.json', 'init=/tmp/tmptf6ftfrp/conxhq3w.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model1okdfpng/prophet_model-20240721141027.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/gsx593fb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/driuozv_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72708', 'data', 'file=/tmp/tmptf6ftfrp/gsx593fb.json', 'init=/tmp/tmptf6ftfrp/driuozv_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelot3lqkqo/prophet_model-20240721141027.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 6.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/06ju5u5b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/h846pa_x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80097', 'data', 'file=/tmp/tmptf6ftfrp/06ju5u5b.json', 'init=/tmp/tmptf6ftfrp/h846pa_x.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpkhqtlip/prophet_model-20240721141027.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/x5iijkhk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/5fe3ror0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76181', 'data', 'file=/tmp/tmptf6ftfrp/x5iijkhk.json', 'init=/tmp/tmptf6ftfrp/5fe3ror0.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0y44a6z8/prophet_model-20240721141028.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0qbkgnb0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/oythk6hs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26739', 'data', 'file=/tmp/tmptf6ftfrp/0qbkgnb0.json', 'init=/tmp/tmptf6ftfrp/oythk6hs.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelzh53v80w/prophet_model-20240721141028.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/m1t3t3g0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dmeko5nf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57498', 'data', 'file=/tmp/tmptf6ftfrp/m1t3t3g0.json', 'init=/tmp/tmptf6ftfrp/dmeko5nf.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelovlv8yrw/prophet_model-20240721141028.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 17.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3_ipb13i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/eqrbyc9x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19733', 'data', 'file=/tmp/tmptf6ftfrp/3_ipb13i.json', 'init=/tmp/tmptf6ftfrp/eqrbyc9x.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelhgbmt9ox/prophet_model-20240721141028.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/5qjmb4ys.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/h7axvyxr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68323', 'data', 'file=/tmp/tmptf6ftfrp/5qjmb4ys.json', 'init=/tmp/tmptf6ftfrp/h7axvyxr.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelb4p21x1f/prophet_model-20240721141028.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hcv936ai.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/gn5bw5l9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34850', 'data', 'file=/tmp/tmptf6ftfrp/hcv936ai.json', 'init=/tmp/tmptf6ftfrp/gn5bw5l9.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model3aer5ti6/prophet_model-20240721141029.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
results['is_weekend'] = results['is_weekend'].astype(int)
results['season'] = results['season'].astype(int)

results.head(15) # 정수로 표시되었는지 확인
# Out:
#    order_date product_category_name  season  is_weekend    demand
# 0  2019-08-01         fashion_shoes       4           0  1.366129
# 1  2019-08-02         fashion_shoes       4           0  1.290840
# 2  2019-08-03         fashion_shoes       4           1  1.128064
# 3  2019-08-04         fashion_shoes       4           1  1.192414
# 4  2019-08-05         fashion_shoes       4           0  1.114627
# 5  2019-08-06         fashion_shoes       4           0  1.409516
# 6  2019-08-07         fashion_shoes       4           0  1.060140
# 7  2019-08-08         fashion_shoes       4           0  1.362917
# 8  2019-08-09         fashion_shoes       4           0  1.287628
# 9  2019-08-10         fashion_shoes       4           1  1.124852
# 10 2019-08-11         fashion_shoes       4           1  1.189202
# 11 2019-08-12         fashion_shoes       4           0  1.111415
# 12 2019-08-13         fashion_shoes       4           0  1.406304
# 13 2019-08-14         fashion_shoes       4           0  1.056928
# 14 2019-08-15         fashion_shoes       4           0  1.359705

# %%
results_august = results.copy()
results_august.head()
# Out:
#   order_date product_category_name  season  is_weekend    demand
# 0 2019-08-01         fashion_shoes       4           0  1.366129
# 1 2019-08-02         fashion_shoes       4           0  1.290840
# 2 2019-08-03         fashion_shoes       4           1  1.128064
# 3 2019-08-04         fashion_shoes       4           1  1.192414
# 4 2019-08-05         fashion_shoes       4           0  1.114627

# %%
results_august.to_csv('results_august.csv', index=False)

# %%
category_demand = results_august.groupby('product_category_name')['demand'].sum().reset_index()

category_demand = category_demand.sort_values(by='demand', ascending=False)

top_5_categories = category_demand.head(10)

print("8월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:")
print(top_5_categories)
# Out:
# 8월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:
#     product_category_name      demand
# 38          health_beauty  773.258055
# 8          bed_bath_table  622.618686
# 44         home_utilities  563.124970
# 71          watches_gifts  525.073690
# 35        furniture_decor  394.037190
# 64         sports_leisure  280.994785
# 6              automotive  269.392456
# 7                    baby  217.834986
# 37           garden_tools  191.840781
# 14  computers_accessories  191.357037

# %% [markdown]
# # 9월 데이터셋에도 적용

# %%
# 2019년 9월 데이터셋 만들기

def get_season(month):
    if month in [12, 1, 2]:
        return 2  # Summer
    elif month in [3, 4, 5]:
        return 3  # Autumn
    elif month in [6, 7, 8]:
        return 4  # Winter
    else:
        return 1  # Spring

demand_df['season'] = demand_df['order_date'].dt.month.apply(get_season)

dates = pd.date_range(start='2019-09-01', end='2019-09-30', freq='D')

date_list = []

for date in dates:
    date_list.append({'date': date})

X_september = pd.DataFrame(date_list)

X_september['product_category_name'] = ''

X_september['is_weekend'] = X_september['date'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

X_september['season'] = X_september['date'].dt.month.apply(get_season)

X_september.head()
# Out:
#         date product_category_name  is_weekend  season
# 0 2019-09-01                                 1       1
# 1 2019-09-02                                 0       1
# 2 2019-09-03                                 0       1
# 3 2019-09-04                                 0       1
# 4 2019-09-05                                 0       1

# %%
# 카테고리별로 모델을 훈련하고 예측
results = pd.DataFrame()

for category in demand_df['product_category_name'].unique():
    group = demand_df[demand_df['product_category_name'] == category]

    if not group.empty:  # 카테고리가 존재하는 경우에만 진행

        group = group.rename(columns={'order_date': 'ds', 'demand': 'y', 'season': 'season', 'is_weekend': 'is_weekend'})

        model = Prophet()

        model.add_regressor('season')
        model.add_regressor('is_weekend')

        model.fit(group[['ds', 'y', 'season', 'is_weekend']])

        future = X_september.rename(columns={'date': 'ds'})

        future['season'] = future['ds'].dt.month.apply(get_season)
        future['is_weekend'] = future['ds'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

        forecast = model.predict(future)

        forecast['season'] = future['season'].values
        forecast['is_weekend'] = future['is_weekend'].values

        # 결과 저장  # 주말여부 및 계절 정보 함께 출력 -- 분석에 사용
        forecast['product_category_name'] = category
        forecast['order_date'] = forecast['ds']
        forecast['demand'] = forecast['yhat']
        results = pd.concat([results, forecast[['order_date', 'product_category_name', 'demand', 'season', 'is_weekend']]])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/99r_g1fo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8p3khw6a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46201', 'data', 'file=/tmp/tmptf6ftfrp/99r_g1fo.json', 'init=/tmp/tmptf6ftfrp/8p3khw6a.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model12o0m9w8/prophet_model-20240721141029.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/nq7330_7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/kzuule5p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46004', 'data', 'file=/tmp/tmptf6ftfrp/nq7330_7.json', 'init=/tmp/tmptf6ftfrp/kzuule5p.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelnx22jc4o/prophet_model-20240721141029.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1ogtrxwt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/167sx2eg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73911', 'data', 'file=/tmp/tmptf6ftfrp/1ogtrxwt.json', 'init=/tmp/tmptf6ftfrp/167sx2eg.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeljics6cpl/prophet_model-20240721141029.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/tqjcwark.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7ki71mit.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52904', 'data', 'file=/tmp/tmptf6ftfrp/tqjcwark.json', 'init=/tmp/tmptf6ftfrp/7ki71mit.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelx0fdf2h6/prophet_model-20240721141030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dt548my6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0iy7xuw9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82781', 'data', 'file=/tmp/tmptf6ftfrp/dt548my6.json', 'init=/tmp/tmptf6ftfrp/0iy7xuw9.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldak18ptl/prophet_model-20240721141030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/c4g2fc4l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6v_zn9uw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77653', 'data', 'file=/tmp/tmptf6ftfrp/c4g2fc4l.json', 'init=/tmp/tmptf6ftfrp/6v_zn9uw.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelch7w82fx/prophet_model-20240721141030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/v1srcjnq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/13zhstr3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87945', 'data', 'file=/tmp/tmptf6ftfrp/v1srcjnq.json', 'init=/tmp/tmptf6ftfrp/13zhstr3.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelw7rrzcgy/prophet_model-20240721141030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/aopj7z6v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/2_zoqopv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43741', 'data', 'file=/tmp/tmptf6ftfrp/aopj7z6v.json', 'init=/tmp/tmptf6ftfrp/2_zoqopv.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelks51_k_o/prophet_model-20240721141030.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/wf06o3g4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ye8lfljv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7205', 'data', 'file=/tmp/tmptf6ftfrp/wf06o3g4.json', 'init=/tmp/tmptf6ftfrp/ye8lfljv.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeljt64vcdf/prophet_model-20240721141031.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ct2ehv64.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1mbmyikj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1863', 'data', 'file=/tmp/tmptf6ftfrp/ct2ehv64.json', 'init=/tmp/tmptf6ftfrp/1mbmyikj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model6mpkx4us/prophet_model-20240721141031.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7hal7_d0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hyfkw_os.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40217', 'data', 'file=/tmp/tmptf6ftfrp/7hal7_d0.json', 'init=/tmp/tmptf6ftfrp/hyfkw_os.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelsraklfcy/prophet_model-20240721141031.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/a8jjtxow.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1sxapqni.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19496', 'data', 'file=/tmp/tmptf6ftfrp/a8jjtxow.json', 'init=/tmp/tmptf6ftfrp/1sxapqni.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmskdfx18/prophet_model-20240721141031.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1l1q_qbl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/4i1hzm47.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40802', 'data', 'file=/tmp/tmptf6ftfrp/1l1q_qbl.json', 'init=/tmp/tmptf6ftfrp/4i1hzm47.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modell4rmsb9g/prophet_model-20240721141031.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9mcvt7zt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0njf9fvf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46508', 'data', 'file=/tmp/tmptf6ftfrp/9mcvt7zt.json', 'init=/tmp/tmptf6ftfrp/0njf9fvf.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelsnahkhxl/prophet_model-20240721141032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/zsnadpa4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/g38hjub6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76705', 'data', 'file=/tmp/tmptf6ftfrp/zsnadpa4.json', 'init=/tmp/tmptf6ftfrp/g38hjub6.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model3p28zbku/prophet_model-20240721141032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/eyandl15.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/uk881biy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35464', 'data', 'file=/tmp/tmptf6ftfrp/eyandl15.json', 'init=/tmp/tmptf6ftfrp/uk881biy.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldp0chpd8/prophet_model-20240721141032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/uer_hbcm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/lh3be_mb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32003', 'data', 'file=/tmp/tmptf6ftfrp/uer_hbcm.json', 'init=/tmp/tmptf6ftfrp/lh3be_mb.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldvp79ipj/prophet_model-20240721141032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/4oo640gy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/o2b_zd_j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10039', 'data', 'file=/tmp/tmptf6ftfrp/4oo640gy.json', 'init=/tmp/tmptf6ftfrp/o2b_zd_j.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model1sa48d3_/prophet_model-20240721141032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0q477v7p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9yufhe0q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99205', 'data', 'file=/tmp/tmptf6ftfrp/0q477v7p.json', 'init=/tmp/tmptf6ftfrp/9yufhe0q.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model1gvd42hz/prophet_model-20240721141033.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/begst9d4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ys9e7fop.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98046', 'data', 'file=/tmp/tmptf6ftfrp/begst9d4.json', 'init=/tmp/tmptf6ftfrp/ys9e7fop.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelhi205r47/prophet_model-20240721141033.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1y4v1euy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/o85vov_3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37503', 'data', 'file=/tmp/tmptf6ftfrp/1y4v1euy.json', 'init=/tmp/tmptf6ftfrp/o85vov_3.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelnzxi8qmf/prophet_model-20240721141033.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/b4uy1v_9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/sdk3wykj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98976', 'data', 'file=/tmp/tmptf6ftfrp/b4uy1v_9.json', 'init=/tmp/tmptf6ftfrp/sdk3wykj.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeluxozjr3r/prophet_model-20240721141033.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ptrlnur1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/c3odsibh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33372', 'data', 'file=/tmp/tmptf6ftfrp/ptrlnur1.json', 'init=/tmp/tmptf6ftfrp/c3odsibh.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0kmvqut4/prophet_model-20240721141034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7jp5wpkj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hkry1iwo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33458', 'data', 'file=/tmp/tmptf6ftfrp/7jp5wpkj.json', 'init=/tmp/tmptf6ftfrp/hkry1iwo.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeltswu5rrh/prophet_model-20240721141034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/796xnzqh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/3j9kib_g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2510', 'data', 'file=/tmp/tmptf6ftfrp/796xnzqh.json', 'init=/tmp/tmptf6ftfrp/3j9kib_g.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelwcn6scie/prophet_model-20240721141034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/gspzqst_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/soyoor92.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27561', 'data', 'file=/tmp/tmptf6ftfrp/gspzqst_.json', 'init=/tmp/tmptf6ftfrp/soyoor92.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelou2i8270/prophet_model-20240721141034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9xfo88oz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/2_qgca79.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29782', 'data', 'file=/tmp/tmptf6ftfrp/9xfo88oz.json', 'init=/tmp/tmptf6ftfrp/2_qgca79.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modell8tdw9qg/prophet_model-20240721141034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/aj0f7q93.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/izbludb0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13836', 'data', 'file=/tmp/tmptf6ftfrp/aj0f7q93.json', 'init=/tmp/tmptf6ftfrp/izbludb0.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model20wt1y2c/prophet_model-20240721141034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z2bp6cpe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/80dikfjk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12949', 'data', 'file=/tmp/tmptf6ftfrp/z2bp6cpe.json', 'init=/tmp/tmptf6ftfrp/80dikfjk.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeljdugd964/prophet_model-20240721141035.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/szfaexei.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7afedv7y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37712', 'data', 'file=/tmp/tmptf6ftfrp/szfaexei.json', 'init=/tmp/tmptf6ftfrp/7afedv7y.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelorraurmw/prophet_model-20240721141035.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1tdfsy99.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/q47mydr5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3977', 'data', 'file=/tmp/tmptf6ftfrp/1tdfsy99.json', 'init=/tmp/tmptf6ftfrp/q47mydr5.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmzqk2rhv/prophet_model-20240721141035.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/pfkkt7jk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/c8lt621x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92967', 'data', 'file=/tmp/tmptf6ftfrp/pfkkt7jk.json', 'init=/tmp/tmptf6ftfrp/c8lt621x.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmoxliorl/prophet_model-20240721141036.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/du6z40sd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/p1mdpfuz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43765', 'data', 'file=/tmp/tmptf6ftfrp/du6z40sd.json', 'init=/tmp/tmptf6ftfrp/p1mdpfuz.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model06p8dnbg/prophet_model-20240721141036.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/n4i24vuw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/orq6v7ey.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96646', 'data', 'file=/tmp/tmptf6ftfrp/n4i24vuw.json', 'init=/tmp/tmptf6ftfrp/orq6v7ey.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model79xirhjh/prophet_model-20240721141036.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6ru485zj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/q4h4i_p1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25793', 'data', 'file=/tmp/tmptf6ftfrp/6ru485zj.json', 'init=/tmp/tmptf6ftfrp/q4h4i_p1.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model0w6xlgg4/prophet_model-20240721141037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/17vgqlod.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8p4rdosm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78740', 'data', 'file=/tmp/tmptf6ftfrp/17vgqlod.json', 'init=/tmp/tmptf6ftfrp/8p4rdosm.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeliqpcfuc2/prophet_model-20240721141037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/qj42w0k0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/s14ynta3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9354', 'data', 'file=/tmp/tmptf6ftfrp/qj42w0k0.json', 'init=/tmp/tmptf6ftfrp/s14ynta3.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelzcx1290d/prophet_model-20240721141037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vw1pkcav.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dxxarrrr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60647', 'data', 'file=/tmp/tmptf6ftfrp/vw1pkcav.json', 'init=/tmp/tmptf6ftfrp/dxxarrrr.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelonywm4tq/prophet_model-20240721141037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 0.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/z_x512ls.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/cq3r08_5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84354', 'data', 'file=/tmp/tmptf6ftfrp/z_x512ls.json', 'init=/tmp/tmptf6ftfrp/cq3r08_5.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelusxoqpwz/prophet_model-20240721141038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/aro3khvl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/h0x7w15_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91130', 'data', 'file=/tmp/tmptf6ftfrp/aro3khvl.json', 'init=/tmp/tmptf6ftfrp/h0x7w15_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelk54e6ul_/prophet_model-20240721141038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/qeqfxc5h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/el30wr2i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59848', 'data', 'file=/tmp/tmptf6ftfrp/qeqfxc5h.json', 'init=/tmp/tmptf6ftfrp/el30wr2i.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelmgwjndkn/prophet_model-20240721141038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/c852a_ka.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/n99jcjeo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39687', 'data', 'file=/tmp/tmptf6ftfrp/c852a_ka.json', 'init=/tmp/tmptf6ftfrp/n99jcjeo.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelkjvr73kj/prophet_model-20240721141039.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0p_qasqf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/t6b9tg6o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28843', 'data', 'file=/tmp/tmptf6ftfrp/0p_qasqf.json', 'init=/tmp/tmptf6ftfrp/t6b9tg6o.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelgqw9vmgq/prophet_model-20240721141039.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/8d4lcqkt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/4ovsioq_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17965', 'data', 'file=/tmp/tmptf6ftfrp/8d4lcqkt.json', 'init=/tmp/tmptf6ftfrp/4ovsioq_.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelqk14atkh/prophet_model-20240721141039.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dyebo9el.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/lte40vuk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98401', 'data', 'file=/tmp/tmptf6ftfrp/dyebo9el.json', 'init=/tmp/tmptf6ftfrp/lte40vuk.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelz61px3gd/prophet_model-20240721141039.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/iz8925du.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/zkw6klc6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24784', 'data', 'file=/tmp/tmptf6ftfrp/iz8925du.json', 'init=/tmp/tmptf6ftfrp/zkw6klc6.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modello0r98jc/prophet_model-20240721141040.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0lvlbj10.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1xq1l22e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32249', 'data', 'file=/tmp/tmptf6ftfrp/0lvlbj10.json', 'init=/tmp/tmptf6ftfrp/1xq1l22e.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelwnusqks2/prophet_model-20240721141040.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/nbvroxmv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rmtmejmu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83022', 'data', 'file=/tmp/tmptf6ftfrp/nbvroxmv.json', 'init=/tmp/tmptf6ftfrp/rmtmejmu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelfhedzgx5/prophet_model-20240721141040.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ki0n9qco.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vy01vyq6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26460', 'data', 'file=/tmp/tmptf6ftfrp/ki0n9qco.json', 'init=/tmp/tmptf6ftfrp/vy01vyq6.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelflkwnhi7/prophet_model-20240721141040.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7igzkgwi.json
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vi5hsd9g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/7t0fpdk1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85802', 'data', 'file=/tmp/tmptf6ftfrp/vi5hsd9g.json', 'init=/tmp/tmptf6ftfrp/7t0fpdk1.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeltouz_1te/prophet_model-20240721141041.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/t7kjwler.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/na682dxg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90680', 'data', 'file=/tmp/tmptf6ftfrp/t7kjwler.json', 'init=/tmp/tmptf6ftfrp/na682dxg.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldxsp7li7/prophet_model-20240721141042.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/uavsbwcd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ecm9s_q0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28626', 'data', 'file=/tmp/tmptf6ftfrp/uavsbwcd.json', 'init=/tmp/tmptf6ftfrp/ecm9s_q0.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelk6jclbua/prophet_model-20240721141042.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/tiz5dt1o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/f6gy_8_a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36688', 'data', 'file=/tmp/tmptf6ftfrp/tiz5dt1o.json', 'init=/tmp/tmptf6ftfrp/f6gy_8_a.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelsz0klhfz/prophet_model-20240721141042.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_gazk1_d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6cxh08xa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14387', 'data', 'file=/tmp/tmptf6ftfrp/_gazk1_d.json', 'init=/tmp/tmptf6ftfrp/6cxh08xa.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelaxftnpsz/prophet_model-20240721141042.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/1uuhvtiw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/_p029xu3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67545', 'data', 'file=/tmp/tmptf6ftfrp/1uuhvtiw.json', 'init=/tmp/tmptf6ftfrp/_p029xu3.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelhb8wgxoa/prophet_model-20240721141042.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/dch1s_os.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/smx553_l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28610', 'data', 'file=/tmp/tmptf6ftfrp/dch1s_os.json', 'init=/tmp/tmptf6ftfrp/smx553_l.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeldnzsdc5s/prophet_model-20240721141043.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/syvdbpei.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/9csfebua.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85625', 'data', 'file=/tmp/tmptf6ftfrp/syvdbpei.json', 'init=/tmp/tmptf6ftfrp/9csfebua.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model8go6c4a1/prophet_model-20240721141043.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/x124p2_5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/vj7jsvgx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36782', 'data', 'file=/tmp/tmptf6ftfrp/x124p2_5.json', 'init=/tmp/tmptf6ftfrp/vj7jsvgx.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model9j4j6itd/prophet_model-20240721141043.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 6.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/fb_7h95g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/4d5unao7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62683', 'data', 'file=/tmp/tmptf6ftfrp/fb_7h95g.json', 'init=/tmp/tmptf6ftfrp/4d5unao7.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelc2yuxi08/prophet_model-20240721141044.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/mu1mgcrg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/ywuwggto.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49738', 'data', 'file=/tmp/tmptf6ftfrp/mu1mgcrg.json', 'init=/tmp/tmptf6ftfrp/ywuwggto.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelzboqce9x/prophet_model-20240721141044.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 8.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/elqa3sqd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/hr_cyi6u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89329', 'data', 'file=/tmp/tmptf6ftfrp/elqa3sqd.json', 'init=/tmp/tmptf6ftfrp/hr_cyi6u.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeleg6x7ftw/prophet_model-20240721141044.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/tvyiszsa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/muy5hs5a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66059', 'data', 'file=/tmp/tmptf6ftfrp/tvyiszsa.json', 'init=/tmp/tmptf6ftfrp/muy5hs5a.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelpdbvd918/prophet_model-20240721141044.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 17.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/6d85czuo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/0e1enpqk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62590', 'data', 'file=/tmp/tmptf6ftfrp/6d85czuo.json', 'init=/tmp/tmptf6ftfrp/0e1enpqk.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modeli0_np1ft/prophet_model-20240721141044.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/l2uxfdkl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/lm1rsl8m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98120', 'data', 'file=/tmp/tmptf6ftfrp/l2uxfdkl.json', 'init=/tmp/tmptf6ftfrp/lm1rsl8m.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_modelj105w7t5/prophet_model-20240721141045.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:10:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/cyvdspze.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptf6ftfrp/rm1tu8zu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1108', 'data', 'file=/tmp/tmptf6ftfrp/cyvdspze.json', 'init=/tmp/tmptf6ftfrp/rm1tu8zu.json', 'output', 'file=/tmp/tmptf6ftfrp/prophet_model_mqu1nxk/prophet_model-20240721141045.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 14:10:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:10:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
results['is_weekend'] = results['is_weekend'].astype(int)
results['season'] = results['season'].astype(int)

results.head(15) # 정수로 표시되었는지 확인
# Out:
#    order_date product_category_name    demand  season  is_weekend
# 0  2019-09-01         fashion_shoes  1.310319       1           1
# 1  2019-09-02         fashion_shoes  1.232531       1           0
# 2  2019-09-03         fashion_shoes  1.527420       1           0
# 3  2019-09-04         fashion_shoes  1.178044       1           0
# 4  2019-09-05         fashion_shoes  1.480821       1           0
# 5  2019-09-06         fashion_shoes  1.405533       1           0
# 6  2019-09-07         fashion_shoes  1.242757       1           1
# 7  2019-09-08         fashion_shoes  1.307107       1           1
# 8  2019-09-09         fashion_shoes  1.229319       1           0
# 9  2019-09-10         fashion_shoes  1.524209       1           0
# 10 2019-09-11         fashion_shoes  1.174832       1           0
# 11 2019-09-12         fashion_shoes  1.477609       1           0
# 12 2019-09-13         fashion_shoes  1.402321       1           0
# 13 2019-09-14         fashion_shoes  1.239545       1           1
# 14 2019-09-15         fashion_shoes  1.303895       1           1

# %%
results_september = results.copy()
results_september.head()
# Out:
#   order_date product_category_name    demand  season  is_weekend
# 0 2019-09-01         fashion_shoes  1.310319       1           1
# 1 2019-09-02         fashion_shoes  1.232531       1           0
# 2 2019-09-03         fashion_shoes  1.527420       1           0
# 3 2019-09-04         fashion_shoes  1.178044       1           0
# 4 2019-09-05         fashion_shoes  1.480821       1           0

# %%
results_september.to_csv('results_september.csv', index=False)

# %%
category_demand_september = results_september.groupby('product_category_name')['demand'].sum().reset_index()

category_demand_september = category_demand_september.sort_values(by='demand', ascending=False)

top_5_categories = category_demand_september.head(10)

print("9월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:")
print(top_5_categories)
# Out:
# 9월에 가장 수요가 많을 것으로 예상되는 카테고리 10개:
#    product_category_name      demand
# 38         health_beauty  786.283578
# 71         watches_gifts  614.033196
# 8         bed_bath_table  591.318865
# 44        home_utilities  506.626352
# 35       furniture_decor  463.066432
# 37          garden_tools  270.773206
# 6             automotive  242.297432
# 7                   baby  242.054481
# 64        sports_leisure  223.078903
# 59             perfumery  213.336913
